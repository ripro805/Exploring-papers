# %% [markdown]
# <a href="https://colab.research.google.com/github/ripro805/Exploring-papers/blob/main/Copy_of_Brain_Tumor_Classification_using_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.nature.com/articles/s41598-025-03752-8

# %%
import os
import requests
import zipfile
import numpy as np
from scipy.io import loadmat
from PIL import Image

# Step 1: Download the Dataset
url = 'https://figshare.com/ndownloader/articles/1512427/versions/8'
output_path = 'brain_tumor_dataset.zip'

print("Downloading dataset...")
response = requests.get(url)
with open(output_path, 'wb') as file:
    file.write(response.content)
print("Download completed.")

# Step 2: Extract the Dataset
extract_dir = 'brain_tumor_dataset'
os.makedirs(extract_dir, exist_ok=True)

print("Extracting dataset...")
with zipfile.ZipFile(output_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)
print(f"Extraction completed. Files are extracted to '{extract_dir}' directory.")

# Verify the structure
print("\nDirectory Structure After Extraction:")
for root, dirs, files in os.walk(extract_dir):
    print(root, "contains", len(files), "files")
# Out:
# Downloading dataset...
# Download completed.
# Extracting dataset...
# Extraction completed. Files are extracted to 'brain_tumor_dataset' directory.
#
# Directory Structure After Extraction:
# brain_tumor_dataset contains 6 files

# %%
import zipfile
import os

base_dir = '/content/brain_tumor_dataset/'
extract_dir = os.path.join(base_dir, 'extracted')

# Make sure extraction directory exists
os.makedirs(extract_dir, exist_ok=True)

# List all .zip files in base_dir
zip_files = [f for f in os.listdir(base_dir) if f.endswith('.zip')]
print(f"Found {len(zip_files)} zip files:")

for zip_file in zip_files:
    zip_path = os.path.join(base_dir, zip_file)
    print(f"Extracting {zip_path} ...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"Extracted {zip_file} to {extract_dir}")

print(f"\nExtraction completed. Total files extracted: {len(os.listdir(extract_dir))}")
# Out:
# Found 4 zip files:
# Extracting /content/brain_tumor_dataset/brainTumorDataPublic_1-766.zip ...
# Extracted brainTumorDataPublic_1-766.zip to /content/brain_tumor_dataset/extracted
# Extracting /content/brain_tumor_dataset/brainTumorDataPublic_1533-2298.zip ...
# Extracted brainTumorDataPublic_1533-2298.zip to /content/brain_tumor_dataset/extracted
# Extracting /content/brain_tumor_dataset/brainTumorDataPublic_2299-3064.zip ...
# Extracted brainTumorDataPublic_2299-3064.zip to /content/brain_tumor_dataset/extracted
# Extracting /content/brain_tumor_dataset/brainTumorDataPublic_767-1532.zip ...
# Extracted brainTumorDataPublic_767-1532.zip to /content/brain_tumor_dataset/extracted
#
# Extraction completed. Total files extracted: 3064

# %% [markdown]
# A single .mat file consists of:
#
# PID: Patient ID for that particular tumor image. This is not a necessary feature.
# image: Image of the brain tumor
# label: Label between 1-3 denoting what kind of tumor is present
# tumorBorder: Coordinates of the tumor present in the image
# tumorMask: Masked version of the tumor.
# We'll need the image, label, tumorBorder, tumorMask which are the necessary features that'll help us to detect brain tumors.

# %%
/content/brain_tumor_dataset/extracted/1.mat
# Out:
#   File "/tmp/ipython-input-385622562.py", line 1
#     content/brain_tumor_dataset/extracted/1.mat()
#                                            ^
# SyntaxError: invalid decimal literal

# %%
import h5py
import os

mat_dir = '/content/brain_tumor_dataset/extracted'
problem_files = ['1171.mat', '545.mat']  # files with errors

for file_name in problem_files:
    file_path = os.path.join(mat_dir, file_name)
    try:
        with h5py.File(file_path, 'r') as f:
            print(f"Keys in {file_name}:")
            def printname(name):
                print(name)
            f.visit(printname)
            print("-" * 40)
    except Exception as e:
        print(f"Could not open {file_name}: {e}")
# Out:
# Keys in 1171.mat:
# cjdata
# cjdata/PID
# cjdata/image
# cjdata/label
# cjdata/tumorBorder
# cjdata/tumorMask
# ----------------------------------------
# Keys in 545.mat:
# cjdata
# cjdata/PID
# cjdata/image
# cjdata/label
# cjdata/tumorBorder
# cjdata/tumorMask
# ----------------------------------------

# %%
import h5py
import numpy as np

file_path = '/content/brain_tumor_dataset/extracted/1171.mat'

with h5py.File(file_path, 'r') as f:
    cjdata = f['cjdata']

    # Access 'label'
    label_ref = cjdata['label'][()]  # This is an object reference or array

    # Dereference label if it's a reference
    if isinstance(label_ref, np.ndarray) and label_ref.dtype == 'object':
        label_ref = label_ref[0]

    # If label_ref is a h5py reference, dereference it
    if isinstance(label_ref, h5py.Reference):
        label_data = f[label_ref][()]
    else:
        label_data = label_ref

    print("Label data:", label_data)

    # Similarly for 'image'
    image_ref = cjdata['image'][()]
    if isinstance(image_ref, np.ndarray) and image_ref.dtype == 'object':
        image_ref = image_ref[0]
    if isinstance(image_ref, h5py.Reference):
        image_data = f[image_ref][()]
    else:
        image_data = image_ref

    print("Image data shape:", image_data.shape)
# Out:
# Label data: [[3.]]
# Image data shape: (512, 512)

# %%
import h5py
import numpy as np

file_path = '/content/brain_tumor_dataset/extracted/1171.mat'

with h5py.File(file_path, 'r') as f:
    cjdata = f['cjdata']

    def dereference(ref):
        """ Dereference object references. """
        if isinstance(ref, np.ndarray) and ref.dtype == 'object':
            ref = ref[0]  # Extract the actual reference
        if isinstance(ref, h5py.Reference):
            return f[ref][()]
        return ref

    # Access 'label'
    label_ref = cjdata['label'][()]
    label_data = dereference(label_ref)

    # Convert label to integer if possible
    try:
        label = int(label_data.squeeze())
        print("Label:", label)
    except (ValueError, TypeError):
        print("Error: Invalid label data format")
        label = None

    # Access 'image'
    image_ref = cjdata['image'][()]
    image_data = dereference(image_ref)

    if isinstance(image_data, np.ndarray):
        print("Image data shape:", image_data.shape)
    else:
        print("Error: Image data is not a valid numpy array")
# Out:
# Label: 3
# Image data shape: (512, 512)

# %%
import h5py
import numpy as np
from PIL import Image
import os

def save_image(np_array, path):
    # Save directly as uint16 or uint8 depending on dtype
    # If your data is float or other, cast to uint16 without normalization
    if np_array.dtype != np.uint8:
        if np_array.dtype == np.float32 or np_array.dtype == np.float64:
            # Convert float to uint16 by scaling to max of uint16
            np_array = (np_array * 65535).astype(np.uint16)
        else:
            np_array = np_array.astype(np.uint16)
    img = Image.fromarray(np_array)
    img.save(path)

def extract_data_from_mat(mat_path, output_folder):
    with h5py.File(mat_path, 'r') as f:
        cjdata = f['cjdata']

        def dereference(name):
            ref = cjdata[name][()]
            if isinstance(ref, np.ndarray) and ref.dtype == 'object':
                ref = ref[0]
            if isinstance(ref, h5py.Reference):
                return f[ref][()]
            return ref

        image_data = dereference('image')
        label_data = dereference('label')
        tumor_border = dereference('tumorBorder')
        tumor_mask = dereference('tumorMask')

        # Convert label_data to int
        label = int(label_data.squeeze())

        # Save image as PNG without normalization
        os.makedirs(output_folder, exist_ok=True)
        file_base = os.path.splitext(os.path.basename(mat_path))[0]
        image_path = os.path.join(output_folder, f"{file_base}.png")

        save_image(image_data, image_path)

        # print(f"Saved image for {mat_path} with label {label}")

        return {
            'image_path': image_path,
            'label': label,
            'tumor_border': tumor_border,
            'tumor_mask': tumor_mask
        }

# Example usage:
mat_dir = '/content/brain_tumor_dataset/extracted'
output_dir = '/content/brain_tumor_dataset/images'

# Process all .mat files in the directory
for fname in os.listdir(mat_dir):
    if fname.endswith('.mat'):
        mat_path = os.path.join(mat_dir, fname)
        try:
            info = extract_data_from_mat(mat_path, output_dir)
        except Exception as e:
            print(f"Failed to process {fname}: {e}")

# %%
# !rm -r '/content/brain_tumor_dataset/images'

# %%
import h5py
import numpy as np
from PIL import Image
import os

def save_image(np_array, path):
    """Save the image without normalization or preprocessing."""
    # Save directly as uint16 or uint8 depending on dtype
    if np_array.dtype != np.uint8:
        if np_array.dtype == np.float32 or np_array.dtype == np.float64:
            # Convert float to uint16 by scaling to max of uint16
            np_array = (np_array * 65535).astype(np.uint16)
        else:
            np_array = np_array.astype(np.uint16)
    img = Image.fromarray(np_array)
    img.save(path)

def extract_data_from_mat(mat_path, output_base_folder):
    """Extract image and label from .mat file and save based on label."""
    try:
        with h5py.File(mat_path, 'r') as f:
            cjdata = f['cjdata']

            def dereference(name):
                ref = cjdata[name][()]
                if isinstance(ref, np.ndarray) and ref.dtype == 'object':
                    ref = ref[0]
                if isinstance(ref, h5py.Reference):
                    return f[ref][()]
                return ref

            # Extract image, label, tumor border, and tumor mask
            image_data = dereference('image')
            label_data = dereference('label')

            # Convert label_data to integer
            label = int(label_data.squeeze())

            # Create the label-specific folder if it doesn't exist
            output_folder = os.path.join(output_base_folder, str(label))
            os.makedirs(output_folder, exist_ok=True)

            # Save the image in the respective label folder
            file_base = os.path.splitext(os.path.basename(mat_path))[0]
            image_path = os.path.join(output_folder, f"{file_base}.png")
            save_image(image_data, image_path)

            print(f"Saved image for {mat_path} with label {label} at {image_path}")
            return {
                'image_path': image_path,
                'label': label
            }

    except Exception as e:
        print(f"Failed to process {mat_path}: {e}")

# Set directories
mat_dir = '/content/brain_tumor_dataset/extracted'
output_dir = '/content/brain_tumor_dataset/images'

# Process all .mat files in the directory
for fname in os.listdir(mat_dir):
    if fname.endswith('.mat'):
        mat_path = os.path.join(mat_dir, fname)
        extract_data_from_mat(mat_path, output_dir)

print("Processing complete.")
# Out:
# Saved image for /content/brain_tumor_dataset/extracted/1833.mat with label 3 at /content/brain_tumor_dataset/images/3/1833.png
# Saved image for /content/brain_tumor_dataset/extracted/2771.mat with label 2 at /content/brain_tumor_dataset/images/2/2771.png
# Saved image for /content/brain_tumor_dataset/extracted/936.mat with label 3 at /content/brain_tumor_dataset/images/3/936.png
# Saved image for /content/brain_tumor_dataset/extracted/2139.mat with label 2 at /content/brain_tumor_dataset/images/2/2139.png
# Saved image for /content/brain_tumor_dataset/extracted/1893.mat with label 2 at /content/brain_tumor_dataset/images/2/1893.png
# Saved image for /content/brain_tumor_dataset/extracted/458.mat with label 1 at /content/brain_tumor_dataset/images/1/458.png
# Saved image for /content/brain_tumor_dataset/extracted/551.mat with label 1 at /content/brain_tumor_dataset/images/1/551.png
# Saved image for /content/brain_tumor_dataset/extracted/676.mat with label 1 at /content/brain_tumor_dataset/images/1/676.png
# Saved image for /content/brain_tumor_dataset/extracted/354.mat with label 1 at /content/brain_tumor_dataset/images/1/354.png
# Saved image for /content/brain_tumor_dataset/extracted/696.mat with label 1 at /content/brain_tumor_dataset/images/1/696.png
# Saved image for /content/brain_tumor_dataset/extracted/1760.mat with label 3 at /content/brain_tumor_dataset/images/3/1760.png
# Saved image for /content/brain_tumor_dataset/extracted/413.mat with label 1 at /content/brain_tumor_dataset/images/1/413.png
# Saved image for /content/brain_tumor_dataset/extracted/174.mat with label 1 at /content/brain_tumor_dataset/images/1/174.png
# Saved image for /content/brain_tumor_dataset/extracted/1964.mat with label 2 at /content/brain_tumor_dataset/images/2/1964.png
# Saved image for /content/brain_tumor_dataset/extracted/2780.mat with label 2 at /content/brain_tumor_dataset/images/2/2780.png
# Saved image for /content/brain_tumor_dataset/extracted/2024.mat with label 2 at /content/brain_tumor_dataset/images/2/2024.png
# Saved image for /content/brain_tumor_dataset/extracted/2549.mat with label 2 at /content/brain_tumor_dataset/images/2/2549.png
# Saved image for /content/brain_tumor_dataset/extracted/658.mat with label 1 at /content/brain_tumor_dataset/images/1/658.png
# Saved image for /content/brain_tumor_dataset/extracted/1273.mat with label 3 at /content/brain_tumor_dataset/images/3/1273.png
# Saved image for /content/brain_tumor_dataset/extracted/2532.mat with label 2 at /content/brain_tumor_dataset/images/2/2532.png
# Saved image for /content/brain_tumor_dataset/extracted/2446.mat with label 2 at /content/brain_tumor_dataset/images/2/2446.png
# Saved image for /content/brain_tumor_dataset/extracted/317.mat with label 1 at /content/brain_tumor_dataset/images/1/317.png
# Saved image for /content/brain_tumor_dataset/extracted/2493.mat with label 2 at /content/brain_tumor_dataset/images/2/2493.png
# Saved image for /content/brain_tumor_dataset/extracted/773.mat with label 2 at /content/brain_tumor_dataset/images/2/773.png
# Saved image for /content/brain_tumor_dataset/extracted/2383.mat with label 2 at /content/brain_tumor_dataset/images/2/2383.png
# Saved image for /content/brain_tumor_dataset/extracted/810.mat with label 2 at /content/brain_tumor_dataset/images/2/810.png
# Saved image for /content/brain_tumor_dataset/extracted/2198.mat with label 2 at /content/brain_tumor_dataset/images/2/2198.png
# Saved image for /content/brain_tumor_dataset/extracted/1332.mat with label 3 at /content/brain_tumor_dataset/images/3/1332.png
# Saved image for /content/brain_tumor_dataset/extracted/18.mat with label 1 at /content/brain_tumor_dataset/images/1/18.png
# Saved image for /content/brain_tumor_dataset/extracted/538.mat with label 1 at /content/brain_tumor_dataset/images/1/538.png
# Saved image for /content/brain_tumor_dataset/extracted/2844.mat with label 2 at /content/brain_tumor_dataset/images/2/2844.png
# Saved image for /content/brain_tumor_dataset/extracted/1297.mat with label 3 at /content/brain_tumor_dataset/images/3/1297.png
# Saved image for /content/brain_tumor_dataset/extracted/2051.mat with label 2 at /content/brain_tumor_dataset/images/2/2051.png
# Saved image for /content/brain_tumor_dataset/extracted/139.mat with label 1 at /content/brain_tumor_dataset/images/1/139.png
# Saved image for /content/brain_tumor_dataset/extracted/739.mat with label 2 at /content/brain_tumor_dataset/images/2/739.png
# Saved image for /content/brain_tumor_dataset/extracted/2566.mat with label 2 at /content/brain_tumor_dataset/images/2/2566.png
# Saved image for /content/brain_tumor_dataset/extracted/2380.mat with label 2 at /content/brain_tumor_dataset/images/2/2380.png
# Saved image for /content/brain_tumor_dataset/extracted/787.mat with label 2 at /content/brain_tumor_dataset/images/2/787.png
# Saved image for /content/brain_tumor_dataset/extracted/21.mat with label 1 at /content/brain_tumor_dataset/images/1/21.png
# Saved image for /content/brain_tumor_dataset/extracted/2349.mat with label 2 at /content/brain_tumor_dataset/images/2/2349.png
# Saved image for /content/brain_tumor_dataset/extracted/2737.mat with label 2 at /content/brain_tumor_dataset/images/2/2737.png
# Saved image for /content/brain_tumor_dataset/extracted/1381.mat with label 3 at /content/brain_tumor_dataset/images/3/1381.png
# Saved image for /content/brain_tumor_dataset/extracted/1953.mat with label 2 at /content/brain_tumor_dataset/images/2/1953.png
# Saved image for /content/brain_tumor_dataset/extracted/2107.mat with label 2 at /content/brain_tumor_dataset/images/2/2107.png
# Saved image for /content/brain_tumor_dataset/extracted/2529.mat with label 2 at /content/brain_tumor_dataset/images/2/2529.png
# Saved image for /content/brain_tumor_dataset/extracted/1271.mat with label 3 at /content/brain_tumor_dataset/images/3/1271.png
# Saved image for /content/brain_tumor_dataset/extracted/1799.mat with label 3 at /content/brain_tumor_dataset/images/3/1799.png
# Saved image for /content/brain_tumor_dataset/extracted/1704.mat with label 3 at /content/brain_tumor_dataset/images/3/1704.png
# Saved image for /content/brain_tumor_dataset/extracted/770.mat with label 2 at /content/brain_tumor_dataset/images/2/770.png
# Saved image for /content/brain_tumor_dataset/extracted/1035.mat with label 3 at /content/brain_tumor_dataset/images/3/1035.png
# Saved image for /content/brain_tumor_dataset/extracted/1266.mat with label 3 at /content/brain_tumor_dataset/images/3/1266.png
# Saved image for /content/brain_tumor_dataset/extracted/370.mat with label 1 at /content/brain_tumor_dataset/images/1/370.png
# Saved image for /content/brain_tumor_dataset/extracted/2930.mat with label 2 at /content/brain_tumor_dataset/images/2/2930.png
# Saved image for /content/brain_tumor_dataset/extracted/1393.mat with label 3 at /content/brain_tumor_dataset/images/3/1393.png
# Saved image for /content/brain_tumor_dataset/extracted/558.mat with label 1 at /content/brain_tumor_dataset/images/1/558.png
# Saved image for /content/brain_tumor_dataset/extracted/714.mat with label 3 at /content/brain_tumor_dataset/images/3/714.png
# Saved image for /content/brain_tumor_dataset/extracted/2118.mat with label 2 at /content/brain_tumor_dataset/images/2/2118.png
# Saved image for /content/brain_tumor_dataset/extracted/2415.mat with label 2 at /content/brain_tumor_dataset/images/2/2415.png
# Saved image for /content/brain_tumor_dataset/extracted/1803.mat with label 3 at /content/brain_tumor_dataset/images/3/1803.png
# Saved image for /content/brain_tumor_dataset/extracted/2043.mat with label 2 at /content/brain_tumor_dataset/images/2/2043.png
# Saved image for /content/brain_tumor_dataset/extracted/205.mat with label 1 at /content/brain_tumor_dataset/images/1/205.png
# Saved image for /content/brain_tumor_dataset/extracted/2178.mat with label 2 at /content/brain_tumor_dataset/images/2/2178.png
# Saved image for /content/brain_tumor_dataset/extracted/1281.mat with label 3 at /content/brain_tumor_dataset/images/3/1281.png
# Saved image for /content/brain_tumor_dataset/extracted/2433.mat with label 2 at /content/brain_tumor_dataset/images/2/2433.png
# Saved image for /content/brain_tumor_dataset/extracted/1726.mat with label 3 at /content/brain_tumor_dataset/images/3/1726.png
# Saved image for /content/brain_tumor_dataset/extracted/249.mat with label 1 at /content/brain_tumor_dataset/images/1/249.png
# Saved image for /content/brain_tumor_dataset/extracted/120.mat with label 1 at /content/brain_tumor_dataset/images/1/120.png
# Saved image for /content/brain_tumor_dataset/extracted/2298.mat with label 2 at /content/brain_tumor_dataset/images/2/2298.png
# Saved image for /content/brain_tumor_dataset/extracted/2230.mat with label 2 at /content/brain_tumor_dataset/images/2/2230.png
# Saved image for /content/brain_tumor_dataset/extracted/589.mat with label 1 at /content/brain_tumor_dataset/images/1/589.png
# Saved image for /content/brain_tumor_dataset/extracted/326.mat with label 1 at /content/brain_tumor_dataset/images/1/326.png
# Saved image for /content/brain_tumor_dataset/extracted/1213.mat with label 3 at /content/brain_tumor_dataset/images/3/1213.png
# Saved image for /content/brain_tumor_dataset/extracted/2676.mat with label 2 at /content/brain_tumor_dataset/images/2/2676.png
# Saved image for /content/brain_tumor_dataset/extracted/294.mat with label 1 at /content/brain_tumor_dataset/images/1/294.png
# Saved image for /content/brain_tumor_dataset/extracted/260.mat with label 1 at /content/brain_tumor_dataset/images/1/260.png
# Saved image for /content/brain_tumor_dataset/extracted/546.mat with label 1 at /content/brain_tumor_dataset/images/1/546.png
# Saved image for /content/brain_tumor_dataset/extracted/3034.mat with label 2 at /content/brain_tumor_dataset/images/2/3034.png
# Saved image for /content/brain_tumor_dataset/extracted/2219.mat with label 2 at /content/brain_tumor_dataset/images/2/2219.png
# Saved image for /content/brain_tumor_dataset/extracted/1021.mat with label 3 at /content/brain_tumor_dataset/images/3/1021.png
# Saved image for /content/brain_tumor_dataset/extracted/468.mat with label 1 at /content/brain_tumor_dataset/images/1/468.png
# Saved image for /content/brain_tumor_dataset/extracted/847.mat with label 2 at /content/brain_tumor_dataset/images/2/847.png
# Saved image for /content/brain_tumor_dataset/extracted/1709.mat with label 3 at /content/brain_tumor_dataset/images/3/1709.png
# Saved image for /content/brain_tumor_dataset/extracted/2097.mat with label 2 at /content/brain_tumor_dataset/images/2/2097.png
# Saved image for /content/brain_tumor_dataset/extracted/2609.mat with label 2 at /content/brain_tumor_dataset/images/2/2609.png
# Saved image for /content/brain_tumor_dataset/extracted/1741.mat with label 3 at /content/brain_tumor_dataset/images/3/1741.png
# Saved image for /content/brain_tumor_dataset/extracted/36.mat with label 1 at /content/brain_tumor_dataset/images/1/36.png
# Saved image for /content/brain_tumor_dataset/extracted/1981.mat with label 2 at /content/brain_tumor_dataset/images/2/1981.png
# Saved image for /content/brain_tumor_dataset/extracted/2613.mat with label 2 at /content/brain_tumor_dataset/images/2/2613.png
# Saved image for /content/brain_tumor_dataset/extracted/1632.mat with label 3 at /content/brain_tumor_dataset/images/3/1632.png
# Saved image for /content/brain_tumor_dataset/extracted/2408.mat with label 2 at /content/brain_tumor_dataset/images/2/2408.png
# Saved image for /content/brain_tumor_dataset/extracted/180.mat with label 1 at /content/brain_tumor_dataset/images/1/180.png
# Saved image for /content/brain_tumor_dataset/extracted/264.mat with label 1 at /content/brain_tumor_dataset/images/1/264.png
# Saved image for /content/brain_tumor_dataset/extracted/950.mat with label 3 at /content/brain_tumor_dataset/images/3/950.png
# Saved image for /content/brain_tumor_dataset/extracted/1805.mat with label 3 at /content/brain_tumor_dataset/images/3/1805.png
# Saved image for /content/brain_tumor_dataset/extracted/1573.mat with label 3 at /content/brain_tumor_dataset/images/3/1573.png
# Saved image for /content/brain_tumor_dataset/extracted/825.mat with label 2 at /content/brain_tumor_dataset/images/2/825.png
# Saved image for /content/brain_tumor_dataset/extracted/34.mat with label 1 at /content/brain_tumor_dataset/images/1/34.png
# Saved image for /content/brain_tumor_dataset/extracted/2847.mat with label 2 at /content/brain_tumor_dataset/images/2/2847.png
# Saved image for /content/brain_tumor_dataset/extracted/1857.mat with label 2 at /content/brain_tumor_dataset/images/2/1857.png
# Saved image for /content/brain_tumor_dataset/extracted/710.mat with label 3 at /content/brain_tumor_dataset/images/3/710.png
# Saved image for /content/brain_tumor_dataset/extracted/2397.mat with label 2 at /content/brain_tumor_dataset/images/2/2397.png
# Saved image for /content/brain_tumor_dataset/extracted/3026.mat with label 2 at /content/brain_tumor_dataset/images/2/3026.png
# Saved image for /content/brain_tumor_dataset/extracted/2869.mat with label 2 at /content/brain_tumor_dataset/images/2/2869.png
# Saved image for /content/brain_tumor_dataset/extracted/85.mat with label 1 at /content/brain_tumor_dataset/images/1/85.png
# Saved image for /content/brain_tumor_dataset/extracted/948.mat with label 3 at /content/brain_tumor_dataset/images/3/948.png
# Saved image for /content/brain_tumor_dataset/extracted/2026.mat with label 2 at /content/brain_tumor_dataset/images/2/2026.png
# Saved image for /content/brain_tumor_dataset/extracted/3023.mat with label 2 at /content/brain_tumor_dataset/images/2/3023.png
# Saved image for /content/brain_tumor_dataset/extracted/2114.mat with label 2 at /content/brain_tumor_dataset/images/2/2114.png
# Saved image for /content/brain_tumor_dataset/extracted/389.mat with label 1 at /content/brain_tumor_dataset/images/1/389.png
# Saved image for /content/brain_tumor_dataset/extracted/3039.mat with label 2 at /content/brain_tumor_dataset/images/2/3039.png
# Saved image for /content/brain_tumor_dataset/extracted/2245.mat with label 2 at /content/brain_tumor_dataset/images/2/2245.png
# Saved image for /content/brain_tumor_dataset/extracted/2807.mat with label 2 at /content/brain_tumor_dataset/images/2/2807.png
# Saved image for /content/brain_tumor_dataset/extracted/161.mat with label 1 at /content/brain_tumor_dataset/images/1/161.png
# Saved image for /content/brain_tumor_dataset/extracted/2916.mat with label 2 at /content/brain_tumor_dataset/images/2/2916.png
# Saved image for /content/brain_tumor_dataset/extracted/1163.mat with label 3 at /content/brain_tumor_dataset/images/3/1163.png
# Saved image for /content/brain_tumor_dataset/extracted/336.mat with label 1 at /content/brain_tumor_dataset/images/1/336.png
# Saved image for /content/brain_tumor_dataset/extracted/1900.mat with label 2 at /content/brain_tumor_dataset/images/2/1900.png
# Saved image for /content/brain_tumor_dataset/extracted/383.mat with label 1 at /content/brain_tumor_dataset/images/1/383.png
# Saved image for /content/brain_tumor_dataset/extracted/2615.mat with label 2 at /content/brain_tumor_dataset/images/2/2615.png
# Saved image for /content/brain_tumor_dataset/extracted/1330.mat with label 3 at /content/brain_tumor_dataset/images/3/1330.png
# Saved image for /content/brain_tumor_dataset/extracted/342.mat with label 1 at /content/brain_tumor_dataset/images/1/342.png
# Saved image for /content/brain_tumor_dataset/extracted/37.mat with label 1 at /content/brain_tumor_dataset/images/1/37.png
# Saved image for /content/brain_tumor_dataset/extracted/652.mat with label 1 at /content/brain_tumor_dataset/images/1/652.png
# Saved image for /content/brain_tumor_dataset/extracted/287.mat with label 1 at /content/brain_tumor_dataset/images/1/287.png
# Saved image for /content/brain_tumor_dataset/extracted/2504.mat with label 2 at /content/brain_tumor_dataset/images/2/2504.png
# Saved image for /content/brain_tumor_dataset/extracted/583.mat with label 1 at /content/brain_tumor_dataset/images/1/583.png
# Saved image for /content/brain_tumor_dataset/extracted/1882.mat with label 2 at /content/brain_tumor_dataset/images/2/1882.png
# Saved image for /content/brain_tumor_dataset/extracted/1419.mat with label 3 at /content/brain_tumor_dataset/images/3/1419.png
# Saved image for /content/brain_tumor_dataset/extracted/1315.mat with label 3 at /content/brain_tumor_dataset/images/3/1315.png
# Saved image for /content/brain_tumor_dataset/extracted/2754.mat with label 2 at /content/brain_tumor_dataset/images/2/2754.png
# Saved image for /content/brain_tumor_dataset/extracted/910.mat with label 2 at /content/brain_tumor_dataset/images/2/910.png
# Saved image for /content/brain_tumor_dataset/extracted/442.mat with label 1 at /content/brain_tumor_dataset/images/1/442.png
# Saved image for /content/brain_tumor_dataset/extracted/2064.mat with label 2 at /content/brain_tumor_dataset/images/2/2064.png
# Saved image for /content/brain_tumor_dataset/extracted/1940.mat with label 2 at /content/brain_tumor_dataset/images/2/1940.png
# Saved image for /content/brain_tumor_dataset/extracted/3002.mat with label 2 at /content/brain_tumor_dataset/images/2/3002.png
# Saved image for /content/brain_tumor_dataset/extracted/2267.mat with label 2 at /content/brain_tumor_dataset/images/2/2267.png
# Saved image for /content/brain_tumor_dataset/extracted/25.mat with label 1 at /content/brain_tumor_dataset/images/1/25.png
# Saved image for /content/brain_tumor_dataset/extracted/1897.mat with label 2 at /content/brain_tumor_dataset/images/2/1897.png
# Saved image for /content/brain_tumor_dataset/extracted/1874.mat with label 2 at /content/brain_tumor_dataset/images/2/1874.png
# Saved image for /content/brain_tumor_dataset/extracted/1048.mat with label 3 at /content/brain_tumor_dataset/images/3/1048.png
# Saved image for /content/brain_tumor_dataset/extracted/401.mat with label 1 at /content/brain_tumor_dataset/images/1/401.png
# Saved image for /content/brain_tumor_dataset/extracted/2708.mat with label 2 at /content/brain_tumor_dataset/images/2/2708.png
# Saved image for /content/brain_tumor_dataset/extracted/685.mat with label 1 at /content/brain_tumor_dataset/images/1/685.png
# Saved image for /content/brain_tumor_dataset/extracted/2205.mat with label 2 at /content/brain_tumor_dataset/images/2/2205.png
# Saved image for /content/brain_tumor_dataset/extracted/1583.mat with label 3 at /content/brain_tumor_dataset/images/3/1583.png
# Saved image for /content/brain_tumor_dataset/extracted/2106.mat with label 2 at /content/brain_tumor_dataset/images/2/2106.png
# Saved image for /content/brain_tumor_dataset/extracted/53.mat with label 1 at /content/brain_tumor_dataset/images/1/53.png
# Saved image for /content/brain_tumor_dataset/extracted/2320.mat with label 2 at /content/brain_tumor_dataset/images/2/2320.png
# Saved image for /content/brain_tumor_dataset/extracted/2975.mat with label 2 at /content/brain_tumor_dataset/images/2/2975.png
# Saved image for /content/brain_tumor_dataset/extracted/2127.mat with label 2 at /content/brain_tumor_dataset/images/2/2127.png
# Saved image for /content/brain_tumor_dataset/extracted/1269.mat with label 3 at /content/brain_tumor_dataset/images/3/1269.png
# Saved image for /content/brain_tumor_dataset/extracted/247.mat with label 1 at /content/brain_tumor_dataset/images/1/247.png
# Saved image for /content/brain_tumor_dataset/extracted/553.mat with label 1 at /content/brain_tumor_dataset/images/1/553.png
# Saved image for /content/brain_tumor_dataset/extracted/1240.mat with label 3 at /content/brain_tumor_dataset/images/3/1240.png
# Saved image for /content/brain_tumor_dataset/extracted/475.mat with label 1 at /content/brain_tumor_dataset/images/1/475.png
# Saved image for /content/brain_tumor_dataset/extracted/2937.mat with label 2 at /content/brain_tumor_dataset/images/2/2937.png
# Saved image for /content/brain_tumor_dataset/extracted/769.mat with label 2 at /content/brain_tumor_dataset/images/2/769.png
# Saved image for /content/brain_tumor_dataset/extracted/1733.mat with label 3 at /content/brain_tumor_dataset/images/3/1733.png
# Saved image for /content/brain_tumor_dataset/extracted/1141.mat with label 3 at /content/brain_tumor_dataset/images/3/1141.png
# Saved image for /content/brain_tumor_dataset/extracted/872.mat with label 2 at /content/brain_tumor_dataset/images/2/872.png
# Saved image for /content/brain_tumor_dataset/extracted/2350.mat with label 2 at /content/brain_tumor_dataset/images/2/2350.png
# Saved image for /content/brain_tumor_dataset/extracted/1601.mat with label 3 at /content/brain_tumor_dataset/images/3/1601.png
# Saved image for /content/brain_tumor_dataset/extracted/660.mat with label 1 at /content/brain_tumor_dataset/images/1/660.png
# Saved image for /content/brain_tumor_dataset/extracted/615.mat with label 1 at /content/brain_tumor_dataset/images/1/615.png
# Saved image for /content/brain_tumor_dataset/extracted/1954.mat with label 2 at /content/brain_tumor_dataset/images/2/1954.png
# Saved image for /content/brain_tumor_dataset/extracted/2034.mat with label 2 at /content/brain_tumor_dataset/images/2/2034.png
# Saved image for /content/brain_tumor_dataset/extracted/2656.mat with label 2 at /content/brain_tumor_dataset/images/2/2656.png
# Saved image for /content/brain_tumor_dataset/extracted/2521.mat with label 2 at /content/brain_tumor_dataset/images/2/2521.png
# Saved image for /content/brain_tumor_dataset/extracted/2719.mat with label 2 at /content/brain_tumor_dataset/images/2/2719.png
# Saved image for /content/brain_tumor_dataset/extracted/1735.mat with label 3 at /content/brain_tumor_dataset/images/3/1735.png
# Saved image for /content/brain_tumor_dataset/extracted/2336.mat with label 2 at /content/brain_tumor_dataset/images/2/2336.png
# Saved image for /content/brain_tumor_dataset/extracted/297.mat with label 1 at /content/brain_tumor_dataset/images/1/297.png
# Saved image for /content/brain_tumor_dataset/extracted/795.mat with label 2 at /content/brain_tumor_dataset/images/2/795.png
# Saved image for /content/brain_tumor_dataset/extracted/1431.mat with label 3 at /content/brain_tumor_dataset/images/3/1431.png
# Saved image for /content/brain_tumor_dataset/extracted/1499.mat with label 3 at /content/brain_tumor_dataset/images/3/1499.png
# Saved image for /content/brain_tumor_dataset/extracted/424.mat with label 1 at /content/brain_tumor_dataset/images/1/424.png
# Saved image for /content/brain_tumor_dataset/extracted/2276.mat with label 2 at /content/brain_tumor_dataset/images/2/2276.png
# Saved image for /content/brain_tumor_dataset/extracted/1671.mat with label 3 at /content/brain_tumor_dataset/images/3/1671.png
# Saved image for /content/brain_tumor_dataset/extracted/22.mat with label 1 at /content/brain_tumor_dataset/images/1/22.png
# Saved image for /content/brain_tumor_dataset/extracted/602.mat with label 1 at /content/brain_tumor_dataset/images/1/602.png
# Saved image for /content/brain_tumor_dataset/extracted/2096.mat with label 2 at /content/brain_tumor_dataset/images/2/2096.png
# Saved image for /content/brain_tumor_dataset/extracted/1058.mat with label 3 at /content/brain_tumor_dataset/images/3/1058.png
# Saved image for /content/brain_tumor_dataset/extracted/1067.mat with label 3 at /content/brain_tumor_dataset/images/3/1067.png
# Saved image for /content/brain_tumor_dataset/extracted/1661.mat with label 3 at /content/brain_tumor_dataset/images/3/1661.png
# Saved image for /content/brain_tumor_dataset/extracted/732.mat with label 2 at /content/brain_tumor_dataset/images/2/732.png
# Saved image for /content/brain_tumor_dataset/extracted/2133.mat with label 2 at /content/brain_tumor_dataset/images/2/2133.png
# Saved image for /content/brain_tumor_dataset/extracted/187.mat with label 1 at /content/brain_tumor_dataset/images/1/187.png
# Saved image for /content/brain_tumor_dataset/extracted/3004.mat with label 2 at /content/brain_tumor_dataset/images/2/3004.png
# Saved image for /content/brain_tumor_dataset/extracted/275.mat with label 1 at /content/brain_tumor_dataset/images/1/275.png
# Saved image for /content/brain_tumor_dataset/extracted/2877.mat with label 2 at /content/brain_tumor_dataset/images/2/2877.png
# Saved image for /content/brain_tumor_dataset/extracted/165.mat with label 1 at /content/brain_tumor_dataset/images/1/165.png
# Saved image for /content/brain_tumor_dataset/extracted/1896.mat with label 2 at /content/brain_tumor_dataset/images/2/1896.png
# Saved image for /content/brain_tumor_dataset/extracted/2540.mat with label 2 at /content/brain_tumor_dataset/images/2/2540.png
# Saved image for /content/brain_tumor_dataset/extracted/2647.mat with label 2 at /content/brain_tumor_dataset/images/2/2647.png
# Saved image for /content/brain_tumor_dataset/extracted/1245.mat with label 3 at /content/brain_tumor_dataset/images/3/1245.png
# Saved image for /content/brain_tumor_dataset/extracted/2259.mat with label 2 at /content/brain_tumor_dataset/images/2/2259.png
# Saved image for /content/brain_tumor_dataset/extracted/2733.mat with label 2 at /content/brain_tumor_dataset/images/2/2733.png
# Saved image for /content/brain_tumor_dataset/extracted/1485.mat with label 3 at /content/brain_tumor_dataset/images/3/1485.png
# Saved image for /content/brain_tumor_dataset/extracted/1568.mat with label 3 at /content/brain_tumor_dataset/images/3/1568.png
# Saved image for /content/brain_tumor_dataset/extracted/2738.mat with label 2 at /content/brain_tumor_dataset/images/2/2738.png
# Saved image for /content/brain_tumor_dataset/extracted/2050.mat with label 2 at /content/brain_tumor_dataset/images/2/2050.png
# Saved image for /content/brain_tumor_dataset/extracted/1607.mat with label 3 at /content/brain_tumor_dataset/images/3/1607.png
# Saved image for /content/brain_tumor_dataset/extracted/867.mat with label 2 at /content/brain_tumor_dataset/images/2/867.png
# Saved image for /content/brain_tumor_dataset/extracted/1416.mat with label 3 at /content/brain_tumor_dataset/images/3/1416.png
# Saved image for /content/brain_tumor_dataset/extracted/1138.mat with label 3 at /content/brain_tumor_dataset/images/3/1138.png
# Saved image for /content/brain_tumor_dataset/extracted/2644.mat with label 2 at /content/brain_tumor_dataset/images/2/2644.png
# Saved image for /content/brain_tumor_dataset/extracted/889.mat with label 2 at /content/brain_tumor_dataset/images/2/889.png
# Saved image for /content/brain_tumor_dataset/extracted/703.mat with label 1 at /content/brain_tumor_dataset/images/1/703.png
# Saved image for /content/brain_tumor_dataset/extracted/140.mat with label 1 at /content/brain_tumor_dataset/images/1/140.png
# Saved image for /content/brain_tumor_dataset/extracted/1471.mat with label 3 at /content/brain_tumor_dataset/images/3/1471.png
# Saved image for /content/brain_tumor_dataset/extracted/2698.mat with label 2 at /content/brain_tumor_dataset/images/2/2698.png
# Saved image for /content/brain_tumor_dataset/extracted/2525.mat with label 2 at /content/brain_tumor_dataset/images/2/2525.png
# Saved image for /content/brain_tumor_dataset/extracted/1107.mat with label 3 at /content/brain_tumor_dataset/images/3/1107.png
# Saved image for /content/brain_tumor_dataset/extracted/912.mat with label 2 at /content/brain_tumor_dataset/images/2/912.png
# Saved image for /content/brain_tumor_dataset/extracted/1473.mat with label 3 at /content/brain_tumor_dataset/images/3/1473.png
# Saved image for /content/brain_tumor_dataset/extracted/79.mat with label 1 at /content/brain_tumor_dataset/images/1/79.png
# Saved image for /content/brain_tumor_dataset/extracted/3012.mat with label 2 at /content/brain_tumor_dataset/images/2/3012.png
# Saved image for /content/brain_tumor_dataset/extracted/1346.mat with label 3 at /content/brain_tumor_dataset/images/3/1346.png
# Saved image for /content/brain_tumor_dataset/extracted/153.mat with label 1 at /content/brain_tumor_dataset/images/1/153.png
# Saved image for /content/brain_tumor_dataset/extracted/2210.mat with label 2 at /content/brain_tumor_dataset/images/2/2210.png
# Saved image for /content/brain_tumor_dataset/extracted/1534.mat with label 3 at /content/brain_tumor_dataset/images/3/1534.png
# Saved image for /content/brain_tumor_dataset/extracted/1562.mat with label 3 at /content/brain_tumor_dataset/images/3/1562.png
# Saved image for /content/brain_tumor_dataset/extracted/129.mat with label 1 at /content/brain_tumor_dataset/images/1/129.png
# Saved image for /content/brain_tumor_dataset/extracted/2018.mat with label 2 at /content/brain_tumor_dataset/images/2/2018.png
# Saved image for /content/brain_tumor_dataset/extracted/32.mat with label 1 at /content/brain_tumor_dataset/images/1/32.png
# Saved image for /content/brain_tumor_dataset/extracted/1304.mat with label 3 at /content/brain_tumor_dataset/images/3/1304.png
# Saved image for /content/brain_tumor_dataset/extracted/1532.mat with label 3 at /content/brain_tumor_dataset/images/3/1532.png
# Saved image for /content/brain_tumor_dataset/extracted/1051.mat with label 3 at /content/brain_tumor_dataset/images/3/1051.png
# Saved image for /content/brain_tumor_dataset/extracted/1610.mat with label 3 at /content/brain_tumor_dataset/images/3/1610.png
# Saved image for /content/brain_tumor_dataset/extracted/1813.mat with label 3 at /content/brain_tumor_dataset/images/3/1813.png
# Saved image for /content/brain_tumor_dataset/extracted/352.mat with label 1 at /content/brain_tumor_dataset/images/1/352.png
# Saved image for /content/brain_tumor_dataset/extracted/2130.mat with label 2 at /content/brain_tumor_dataset/images/2/2130.png
# Saved image for /content/brain_tumor_dataset/extracted/2499.mat with label 2 at /content/brain_tumor_dataset/images/2/2499.png
# Saved image for /content/brain_tumor_dataset/extracted/698.mat with label 1 at /content/brain_tumor_dataset/images/1/698.png
# Saved image for /content/brain_tumor_dataset/extracted/1729.mat with label 3 at /content/brain_tumor_dataset/images/3/1729.png
# Saved image for /content/brain_tumor_dataset/extracted/2059.mat with label 2 at /content/brain_tumor_dataset/images/2/2059.png
# Saved image for /content/brain_tumor_dataset/extracted/2986.mat with label 2 at /content/brain_tumor_dataset/images/2/2986.png
# Saved image for /content/brain_tumor_dataset/extracted/1854.mat with label 2 at /content/brain_tumor_dataset/images/2/1854.png
# Saved image for /content/brain_tumor_dataset/extracted/1773.mat with label 3 at /content/brain_tumor_dataset/images/3/1773.png
# Saved image for /content/brain_tumor_dataset/extracted/1080.mat with label 3 at /content/brain_tumor_dataset/images/3/1080.png
# Saved image for /content/brain_tumor_dataset/extracted/28.mat with label 1 at /content/brain_tumor_dataset/images/1/28.png
# Saved image for /content/brain_tumor_dataset/extracted/1590.mat with label 3 at /content/brain_tumor_dataset/images/3/1590.png
# Saved image for /content/brain_tumor_dataset/extracted/822.mat with label 2 at /content/brain_tumor_dataset/images/2/822.png
# Saved image for /content/brain_tumor_dataset/extracted/1353.mat with label 3 at /content/brain_tumor_dataset/images/3/1353.png
# Saved image for /content/brain_tumor_dataset/extracted/1919.mat with label 2 at /content/brain_tumor_dataset/images/2/1919.png
# Saved image for /content/brain_tumor_dataset/extracted/2066.mat with label 2 at /content/brain_tumor_dataset/images/2/2066.png
# Saved image for /content/brain_tumor_dataset/extracted/2524.mat with label 2 at /content/brain_tumor_dataset/images/2/2524.png
# Saved image for /content/brain_tumor_dataset/extracted/2546.mat with label 2 at /content/brain_tumor_dataset/images/2/2546.png
# Saved image for /content/brain_tumor_dataset/extracted/2495.mat with label 2 at /content/brain_tumor_dataset/images/2/2495.png
# Saved image for /content/brain_tumor_dataset/extracted/3054.mat with label 2 at /content/brain_tumor_dataset/images/2/3054.png
# Saved image for /content/brain_tumor_dataset/extracted/1769.mat with label 3 at /content/brain_tumor_dataset/images/3/1769.png
# Saved image for /content/brain_tumor_dataset/extracted/2033.mat with label 2 at /content/brain_tumor_dataset/images/2/2033.png
# Saved image for /content/brain_tumor_dataset/extracted/132.mat with label 1 at /content/brain_tumor_dataset/images/1/132.png
# Saved image for /content/brain_tumor_dataset/extracted/2642.mat with label 2 at /content/brain_tumor_dataset/images/2/2642.png
# Saved image for /content/brain_tumor_dataset/extracted/1665.mat with label 3 at /content/brain_tumor_dataset/images/3/1665.png
# Saved image for /content/brain_tumor_dataset/extracted/707.mat with label 1 at /content/brain_tumor_dataset/images/1/707.png
# Saved image for /content/brain_tumor_dataset/extracted/2045.mat with label 2 at /content/brain_tumor_dataset/images/2/2045.png
# Saved image for /content/brain_tumor_dataset/extracted/587.mat with label 1 at /content/brain_tumor_dataset/images/1/587.png
# Saved image for /content/brain_tumor_dataset/extracted/2042.mat with label 2 at /content/brain_tumor_dataset/images/2/2042.png
# Saved image for /content/brain_tumor_dataset/extracted/2123.mat with label 2 at /content/brain_tumor_dataset/images/2/2123.png
# Saved image for /content/brain_tumor_dataset/extracted/1666.mat with label 3 at /content/brain_tumor_dataset/images/3/1666.png
# Saved image for /content/brain_tumor_dataset/extracted/2090.mat with label 2 at /content/brain_tumor_dataset/images/2/2090.png
# Saved image for /content/brain_tumor_dataset/extracted/3028.mat with label 2 at /content/brain_tumor_dataset/images/2/3028.png
# Saved image for /content/brain_tumor_dataset/extracted/849.mat with label 2 at /content/brain_tumor_dataset/images/2/849.png
# Saved image for /content/brain_tumor_dataset/extracted/2053.mat with label 2 at /content/brain_tumor_dataset/images/2/2053.png
# Saved image for /content/brain_tumor_dataset/extracted/2576.mat with label 2 at /content/brain_tumor_dataset/images/2/2576.png
# Saved image for /content/brain_tumor_dataset/extracted/2785.mat with label 2 at /content/brain_tumor_dataset/images/2/2785.png
# Saved image for /content/brain_tumor_dataset/extracted/480.mat with label 1 at /content/brain_tumor_dataset/images/1/480.png
# Saved image for /content/brain_tumor_dataset/extracted/2547.mat with label 2 at /content/brain_tumor_dataset/images/2/2547.png
# Saved image for /content/brain_tumor_dataset/extracted/191.mat with label 1 at /content/brain_tumor_dataset/images/1/191.png
# Saved image for /content/brain_tumor_dataset/extracted/793.mat with label 2 at /content/brain_tumor_dataset/images/2/793.png
# Saved image for /content/brain_tumor_dataset/extracted/1915.mat with label 2 at /content/brain_tumor_dataset/images/2/1915.png
# Saved image for /content/brain_tumor_dataset/extracted/182.mat with label 1 at /content/brain_tumor_dataset/images/1/182.png
# Saved image for /content/brain_tumor_dataset/extracted/2928.mat with label 2 at /content/brain_tumor_dataset/images/2/2928.png
# Saved image for /content/brain_tumor_dataset/extracted/2179.mat with label 2 at /content/brain_tumor_dataset/images/2/2179.png
# Saved image for /content/brain_tumor_dataset/extracted/1922.mat with label 2 at /content/brain_tumor_dataset/images/2/1922.png
# Saved image for /content/brain_tumor_dataset/extracted/552.mat with label 1 at /content/brain_tumor_dataset/images/1/552.png
# Saved image for /content/brain_tumor_dataset/extracted/2801.mat with label 2 at /content/brain_tumor_dataset/images/2/2801.png
# Saved image for /content/brain_tumor_dataset/extracted/1904.mat with label 2 at /content/brain_tumor_dataset/images/2/1904.png
# Saved image for /content/brain_tumor_dataset/extracted/2796.mat with label 2 at /content/brain_tumor_dataset/images/2/2796.png
# Saved image for /content/brain_tumor_dataset/extracted/1736.mat with label 3 at /content/brain_tumor_dataset/images/3/1736.png
# Saved image for /content/brain_tumor_dataset/extracted/2620.mat with label 2 at /content/brain_tumor_dataset/images/2/2620.png
# Saved image for /content/brain_tumor_dataset/extracted/1835.mat with label 3 at /content/brain_tumor_dataset/images/3/1835.png
# Saved image for /content/brain_tumor_dataset/extracted/2414.mat with label 2 at /content/brain_tumor_dataset/images/2/2414.png
# Saved image for /content/brain_tumor_dataset/extracted/2849.mat with label 2 at /content/brain_tumor_dataset/images/2/2849.png
# Saved image for /content/brain_tumor_dataset/extracted/2109.mat with label 2 at /content/brain_tumor_dataset/images/2/2109.png
# Saved image for /content/brain_tumor_dataset/extracted/271.mat with label 1 at /content/brain_tumor_dataset/images/1/271.png
# Saved image for /content/brain_tumor_dataset/extracted/2675.mat with label 2 at /content/brain_tumor_dataset/images/2/2675.png
# Saved image for /content/brain_tumor_dataset/extracted/985.mat with label 3 at /content/brain_tumor_dataset/images/3/985.png
# Saved image for /content/brain_tumor_dataset/extracted/404.mat with label 1 at /content/brain_tumor_dataset/images/1/404.png
# Saved image for /content/brain_tumor_dataset/extracted/879.mat with label 2 at /content/brain_tumor_dataset/images/2/879.png
# Saved image for /content/brain_tumor_dataset/extracted/2401.mat with label 2 at /content/brain_tumor_dataset/images/2/2401.png
# Saved image for /content/brain_tumor_dataset/extracted/1452.mat with label 3 at /content/brain_tumor_dataset/images/3/1452.png
# Saved image for /content/brain_tumor_dataset/extracted/2669.mat with label 2 at /content/brain_tumor_dataset/images/2/2669.png
# Saved image for /content/brain_tumor_dataset/extracted/86.mat with label 1 at /content/brain_tumor_dataset/images/1/86.png
# Saved image for /content/brain_tumor_dataset/extracted/763.mat with label 2 at /content/brain_tumor_dataset/images/2/763.png
# Saved image for /content/brain_tumor_dataset/extracted/2025.mat with label 2 at /content/brain_tumor_dataset/images/2/2025.png
# Saved image for /content/brain_tumor_dataset/extracted/1290.mat with label 3 at /content/brain_tumor_dataset/images/3/1290.png
# Saved image for /content/brain_tumor_dataset/extracted/1325.mat with label 3 at /content/brain_tumor_dataset/images/3/1325.png
# Saved image for /content/brain_tumor_dataset/extracted/1482.mat with label 3 at /content/brain_tumor_dataset/images/3/1482.png
# Saved image for /content/brain_tumor_dataset/extracted/2806.mat with label 2 at /content/brain_tumor_dataset/images/2/2806.png
# Saved image for /content/brain_tumor_dataset/extracted/1072.mat with label 3 at /content/brain_tumor_dataset/images/3/1072.png
# Saved image for /content/brain_tumor_dataset/extracted/1898.mat with label 2 at /content/brain_tumor_dataset/images/2/1898.png
# Saved image for /content/brain_tumor_dataset/extracted/2116.mat with label 2 at /content/brain_tumor_dataset/images/2/2116.png
# Saved image for /content/brain_tumor_dataset/extracted/1457.mat with label 3 at /content/brain_tumor_dataset/images/3/1457.png
# Saved image for /content/brain_tumor_dataset/extracted/2722.mat with label 2 at /content/brain_tumor_dataset/images/2/2722.png
# Saved image for /content/brain_tumor_dataset/extracted/2119.mat with label 2 at /content/brain_tumor_dataset/images/2/2119.png
# Saved image for /content/brain_tumor_dataset/extracted/1818.mat with label 3 at /content/brain_tumor_dataset/images/3/1818.png
# Saved image for /content/brain_tumor_dataset/extracted/1490.mat with label 3 at /content/brain_tumor_dataset/images/3/1490.png
# Saved image for /content/brain_tumor_dataset/extracted/1592.mat with label 3 at /content/brain_tumor_dataset/images/3/1592.png
# Saved image for /content/brain_tumor_dataset/extracted/393.mat with label 1 at /content/brain_tumor_dataset/images/1/393.png
# Saved image for /content/brain_tumor_dataset/extracted/1376.mat with label 3 at /content/brain_tumor_dataset/images/3/1376.png
# Saved image for /content/brain_tumor_dataset/extracted/1585.mat with label 3 at /content/brain_tumor_dataset/images/3/1585.png
# Saved image for /content/brain_tumor_dataset/extracted/1275.mat with label 3 at /content/brain_tumor_dataset/images/3/1275.png
# Saved image for /content/brain_tumor_dataset/extracted/186.mat with label 1 at /content/brain_tumor_dataset/images/1/186.png
# Saved image for /content/brain_tumor_dataset/extracted/137.mat with label 1 at /content/brain_tumor_dataset/images/1/137.png
# Saved image for /content/brain_tumor_dataset/extracted/2508.mat with label 2 at /content/brain_tumor_dataset/images/2/2508.png
# Saved image for /content/brain_tumor_dataset/extracted/1337.mat with label 3 at /content/brain_tumor_dataset/images/3/1337.png
# Saved image for /content/brain_tumor_dataset/extracted/1321.mat with label 3 at /content/brain_tumor_dataset/images/3/1321.png
# Saved image for /content/brain_tumor_dataset/extracted/1311.mat with label 3 at /content/brain_tumor_dataset/images/3/1311.png
# Saved image for /content/brain_tumor_dataset/extracted/1059.mat with label 3 at /content/brain_tumor_dataset/images/3/1059.png
# Saved image for /content/brain_tumor_dataset/extracted/1351.mat with label 3 at /content/brain_tumor_dataset/images/3/1351.png
# Saved image for /content/brain_tumor_dataset/extracted/491.mat with label 1 at /content/brain_tumor_dataset/images/1/491.png
# Saved image for /content/brain_tumor_dataset/extracted/1963.mat with label 2 at /content/brain_tumor_dataset/images/2/1963.png
# Saved image for /content/brain_tumor_dataset/extracted/2604.mat with label 2 at /content/brain_tumor_dataset/images/2/2604.png
# Saved image for /content/brain_tumor_dataset/extracted/2704.mat with label 2 at /content/brain_tumor_dataset/images/2/2704.png
# Saved image for /content/brain_tumor_dataset/extracted/1505.mat with label 3 at /content/brain_tumor_dataset/images/3/1505.png
# Saved image for /content/brain_tumor_dataset/extracted/541.mat with label 1 at /content/brain_tumor_dataset/images/1/541.png
# Saved image for /content/brain_tumor_dataset/extracted/814.mat with label 2 at /content/brain_tumor_dataset/images/2/814.png
# Saved image for /content/brain_tumor_dataset/extracted/648.mat with label 1 at /content/brain_tumor_dataset/images/1/648.png
# Saved image for /content/brain_tumor_dataset/extracted/1201.mat with label 3 at /content/brain_tumor_dataset/images/3/1201.png
# Saved image for /content/brain_tumor_dataset/extracted/1997.mat with label 2 at /content/brain_tumor_dataset/images/2/1997.png
# Saved image for /content/brain_tumor_dataset/extracted/913.mat with label 2 at /content/brain_tumor_dataset/images/2/913.png
# Saved image for /content/brain_tumor_dataset/extracted/805.mat with label 2 at /content/brain_tumor_dataset/images/2/805.png
# Saved image for /content/brain_tumor_dataset/extracted/939.mat with label 3 at /content/brain_tumor_dataset/images/3/939.png
# Saved image for /content/brain_tumor_dataset/extracted/248.mat with label 1 at /content/brain_tumor_dataset/images/1/248.png
# Saved image for /content/brain_tumor_dataset/extracted/932.mat with label 3 at /content/brain_tumor_dataset/images/3/932.png
# Saved image for /content/brain_tumor_dataset/extracted/1279.mat with label 3 at /content/brain_tumor_dataset/images/3/1279.png
# Saved image for /content/brain_tumor_dataset/extracted/1959.mat with label 2 at /content/brain_tumor_dataset/images/2/1959.png
# Saved image for /content/brain_tumor_dataset/extracted/622.mat with label 1 at /content/brain_tumor_dataset/images/1/622.png
# Saved image for /content/brain_tumor_dataset/extracted/2032.mat with label 2 at /content/brain_tumor_dataset/images/2/2032.png
# Saved image for /content/brain_tumor_dataset/extracted/792.mat with label 2 at /content/brain_tumor_dataset/images/2/792.png
# Saved image for /content/brain_tumor_dataset/extracted/2977.mat with label 2 at /content/brain_tumor_dataset/images/2/2977.png
# Saved image for /content/brain_tumor_dataset/extracted/1131.mat with label 3 at /content/brain_tumor_dataset/images/3/1131.png
# Saved image for /content/brain_tumor_dataset/extracted/601.mat with label 1 at /content/brain_tumor_dataset/images/1/601.png
# Saved image for /content/brain_tumor_dataset/extracted/2957.mat with label 2 at /content/brain_tumor_dataset/images/2/2957.png
# Saved image for /content/brain_tumor_dataset/extracted/1725.mat with label 3 at /content/brain_tumor_dataset/images/3/1725.png
# Saved image for /content/brain_tumor_dataset/extracted/1867.mat with label 2 at /content/brain_tumor_dataset/images/2/1867.png
# Saved image for /content/brain_tumor_dataset/extracted/2882.mat with label 2 at /content/brain_tumor_dataset/images/2/2882.png
# Saved image for /content/brain_tumor_dataset/extracted/2933.mat with label 2 at /content/brain_tumor_dataset/images/2/2933.png
# Saved image for /content/brain_tumor_dataset/extracted/2633.mat with label 2 at /content/brain_tumor_dataset/images/2/2633.png
# Saved image for /content/brain_tumor_dataset/extracted/1400.mat with label 3 at /content/brain_tumor_dataset/images/3/1400.png
# Saved image for /content/brain_tumor_dataset/extracted/1156.mat with label 3 at /content/brain_tumor_dataset/images/3/1156.png
# Saved image for /content/brain_tumor_dataset/extracted/1134.mat with label 3 at /content/brain_tumor_dataset/images/3/1134.png
# Saved image for /content/brain_tumor_dataset/extracted/2982.mat with label 2 at /content/brain_tumor_dataset/images/2/2982.png
# Saved image for /content/brain_tumor_dataset/extracted/2563.mat with label 2 at /content/brain_tumor_dataset/images/2/2563.png
# Saved image for /content/brain_tumor_dataset/extracted/1274.mat with label 3 at /content/brain_tumor_dataset/images/3/1274.png
# Saved image for /content/brain_tumor_dataset/extracted/537.mat with label 1 at /content/brain_tumor_dataset/images/1/537.png
# Saved image for /content/brain_tumor_dataset/extracted/1907.mat with label 2 at /content/brain_tumor_dataset/images/2/1907.png
# Saved image for /content/brain_tumor_dataset/extracted/289.mat with label 1 at /content/brain_tumor_dataset/images/1/289.png
# Saved image for /content/brain_tumor_dataset/extracted/2818.mat with label 2 at /content/brain_tumor_dataset/images/2/2818.png
# Saved image for /content/brain_tumor_dataset/extracted/2339.mat with label 2 at /content/brain_tumor_dataset/images/2/2339.png
# Saved image for /content/brain_tumor_dataset/extracted/487.mat with label 1 at /content/brain_tumor_dataset/images/1/487.png
# Saved image for /content/brain_tumor_dataset/extracted/1227.mat with label 3 at /content/brain_tumor_dataset/images/3/1227.png
# Saved image for /content/brain_tumor_dataset/extracted/1865.mat with label 2 at /content/brain_tumor_dataset/images/2/1865.png
# Saved image for /content/brain_tumor_dataset/extracted/2442.mat with label 2 at /content/brain_tumor_dataset/images/2/2442.png
# Saved image for /content/brain_tumor_dataset/extracted/2108.mat with label 2 at /content/brain_tumor_dataset/images/2/2108.png
# Saved image for /content/brain_tumor_dataset/extracted/1547.mat with label 3 at /content/brain_tumor_dataset/images/3/1547.png
# Saved image for /content/brain_tumor_dataset/extracted/657.mat with label 1 at /content/brain_tumor_dataset/images/1/657.png
# Saved image for /content/brain_tumor_dataset/extracted/2431.mat with label 2 at /content/brain_tumor_dataset/images/2/2431.png
# Saved image for /content/brain_tumor_dataset/extracted/771.mat with label 2 at /content/brain_tumor_dataset/images/2/771.png
# Saved image for /content/brain_tumor_dataset/extracted/1876.mat with label 2 at /content/brain_tumor_dataset/images/2/1876.png
# Saved image for /content/brain_tumor_dataset/extracted/311.mat with label 1 at /content/brain_tumor_dataset/images/1/311.png
# Saved image for /content/brain_tumor_dataset/extracted/91.mat with label 1 at /content/brain_tumor_dataset/images/1/91.png
# Saved image for /content/brain_tumor_dataset/extracted/341.mat with label 1 at /content/brain_tumor_dataset/images/1/341.png
# Saved image for /content/brain_tumor_dataset/extracted/2711.mat with label 2 at /content/brain_tumor_dataset/images/2/2711.png
# Saved image for /content/brain_tumor_dataset/extracted/303.mat with label 1 at /content/brain_tumor_dataset/images/1/303.png
# Saved image for /content/brain_tumor_dataset/extracted/741.mat with label 2 at /content/brain_tumor_dataset/images/2/741.png
# Saved image for /content/brain_tumor_dataset/extracted/2880.mat with label 2 at /content/brain_tumor_dataset/images/2/2880.png
# Saved image for /content/brain_tumor_dataset/extracted/2688.mat with label 2 at /content/brain_tumor_dataset/images/2/2688.png
# ...
# Saved image for /content/brain_tumor_dataset/extracted/2854.mat with label 2 at /content/brain_tumor_dataset/images/2/2854.png
# Saved image for /content/brain_tumor_dataset/extracted/2760.mat with label 2 at /content/brain_tumor_dataset/images/2/2760.png
# Saved image for /content/brain_tumor_dataset/extracted/1972.mat with label 2 at /content/brain_tumor_dataset/images/2/1972.png
# Saved image for /content/brain_tumor_dataset/extracted/1038.mat with label 3 at /content/brain_tumor_dataset/images/3/1038.png
# Saved image for /content/brain_tumor_dataset/extracted/1950.mat with label 2 at /content/brain_tumor_dataset/images/2/1950.png
# Saved image for /content/brain_tumor_dataset/extracted/888.mat with label 2 at /content/brain_tumor_dataset/images/2/888.png
# Saved image for /content/brain_tumor_dataset/extracted/2294.mat with label 2 at /content/brain_tumor_dataset/images/2/2294.png
# Saved image for /content/brain_tumor_dataset/extracted/1539.mat with label 3 at /content/brain_tumor_dataset/images/3/1539.png
# Saved image for /content/brain_tumor_dataset/extracted/812.mat with label 2 at /content/brain_tumor_dataset/images/2/812.png
# Saved image for /content/brain_tumor_dataset/extracted/635.mat with label 1 at /content/brain_tumor_dataset/images/1/635.png
# Saved image for /content/brain_tumor_dataset/extracted/885.mat with label 2 at /content/brain_tumor_dataset/images/2/885.png
# Saved image for /content/brain_tumor_dataset/extracted/1408.mat with label 3 at /content/brain_tumor_dataset/images/3/1408.png
# Saved image for /content/brain_tumor_dataset/extracted/772.mat with label 2 at /content/brain_tumor_dataset/images/2/772.png
# Saved image for /content/brain_tumor_dataset/extracted/963.mat with label 3 at /content/brain_tumor_dataset/images/3/963.png
# Saved image for /content/brain_tumor_dataset/extracted/2947.mat with label 2 at /content/brain_tumor_dataset/images/2/2947.png
# Saved image for /content/brain_tumor_dataset/extracted/134.mat with label 1 at /content/brain_tumor_dataset/images/1/134.png
# Saved image for /content/brain_tumor_dataset/extracted/1383.mat with label 3 at /content/brain_tumor_dataset/images/3/1383.png
# Saved image for /content/brain_tumor_dataset/extracted/2730.mat with label 2 at /content/brain_tumor_dataset/images/2/2730.png
# Saved image for /content/brain_tumor_dataset/extracted/1140.mat with label 3 at /content/brain_tumor_dataset/images/3/1140.png
# Saved image for /content/brain_tumor_dataset/extracted/421.mat with label 1 at /content/brain_tumor_dataset/images/1/421.png
# Saved image for /content/brain_tumor_dataset/extracted/674.mat with label 1 at /content/brain_tumor_dataset/images/1/674.png
# Saved image for /content/brain_tumor_dataset/extracted/1619.mat with label 3 at /content/brain_tumor_dataset/images/3/1619.png
# Saved image for /content/brain_tumor_dataset/extracted/2016.mat with label 2 at /content/brain_tumor_dataset/images/2/2016.png
# Saved image for /content/brain_tumor_dataset/extracted/1064.mat with label 3 at /content/brain_tumor_dataset/images/3/1064.png
# Saved image for /content/brain_tumor_dataset/extracted/213.mat with label 1 at /content/brain_tumor_dataset/images/1/213.png
# Saved image for /content/brain_tumor_dataset/extracted/1577.mat with label 3 at /content/brain_tumor_dataset/images/3/1577.png
# Saved image for /content/brain_tumor_dataset/extracted/1350.mat with label 3 at /content/brain_tumor_dataset/images/3/1350.png
# Saved image for /content/brain_tumor_dataset/extracted/262.mat with label 1 at /content/brain_tumor_dataset/images/1/262.png
# Saved image for /content/brain_tumor_dataset/extracted/782.mat with label 2 at /content/brain_tumor_dataset/images/2/782.png
# Saved image for /content/brain_tumor_dataset/extracted/2910.mat with label 2 at /content/brain_tumor_dataset/images/2/2910.png
# Saved image for /content/brain_tumor_dataset/extracted/1916.mat with label 2 at /content/brain_tumor_dataset/images/2/1916.png
# Saved image for /content/brain_tumor_dataset/extracted/392.mat with label 1 at /content/brain_tumor_dataset/images/1/392.png
# Saved image for /content/brain_tumor_dataset/extracted/1215.mat with label 3 at /content/brain_tumor_dataset/images/3/1215.png
# Saved image for /content/brain_tumor_dataset/extracted/2811.mat with label 2 at /content/brain_tumor_dataset/images/2/2811.png
# Saved image for /content/brain_tumor_dataset/extracted/20.mat with label 1 at /content/brain_tumor_dataset/images/1/20.png
# Saved image for /content/brain_tumor_dataset/extracted/2640.mat with label 2 at /content/brain_tumor_dataset/images/2/2640.png
# Saved image for /content/brain_tumor_dataset/extracted/1613.mat with label 3 at /content/brain_tumor_dataset/images/3/1613.png
# Saved image for /content/brain_tumor_dataset/extracted/1034.mat with label 3 at /content/brain_tumor_dataset/images/3/1034.png
# Saved image for /content/brain_tumor_dataset/extracted/2225.mat with label 2 at /content/brain_tumor_dataset/images/2/2225.png
# Saved image for /content/brain_tumor_dataset/extracted/894.mat with label 2 at /content/brain_tumor_dataset/images/2/894.png
# Saved image for /content/brain_tumor_dataset/extracted/3057.mat with label 2 at /content/brain_tumor_dataset/images/2/3057.png
# Saved image for /content/brain_tumor_dataset/extracted/1259.mat with label 3 at /content/brain_tumor_dataset/images/3/1259.png
# Saved image for /content/brain_tumor_dataset/extracted/1119.mat with label 3 at /content/brain_tumor_dataset/images/3/1119.png
# Saved image for /content/brain_tumor_dataset/extracted/678.mat with label 1 at /content/brain_tumor_dataset/images/1/678.png
# Saved image for /content/brain_tumor_dataset/extracted/1099.mat with label 3 at /content/brain_tumor_dataset/images/3/1099.png
# Saved image for /content/brain_tumor_dataset/extracted/1563.mat with label 3 at /content/brain_tumor_dataset/images/3/1563.png
# Saved image for /content/brain_tumor_dataset/extracted/1829.mat with label 3 at /content/brain_tumor_dataset/images/3/1829.png
# Saved image for /content/brain_tumor_dataset/extracted/1470.mat with label 3 at /content/brain_tumor_dataset/images/3/1470.png
# Saved image for /content/brain_tumor_dataset/extracted/530.mat with label 1 at /content/brain_tumor_dataset/images/1/530.png
# Saved image for /content/brain_tumor_dataset/extracted/2152.mat with label 2 at /content/brain_tumor_dataset/images/2/2152.png
# Saved image for /content/brain_tumor_dataset/extracted/1151.mat with label 3 at /content/brain_tumor_dataset/images/3/1151.png
# Saved image for /content/brain_tumor_dataset/extracted/2256.mat with label 2 at /content/brain_tumor_dataset/images/2/2256.png
# Saved image for /content/brain_tumor_dataset/extracted/506.mat with label 1 at /content/brain_tumor_dataset/images/1/506.png
# Saved image for /content/brain_tumor_dataset/extracted/1283.mat with label 3 at /content/brain_tumor_dataset/images/3/1283.png
# Saved image for /content/brain_tumor_dataset/extracted/1906.mat with label 2 at /content/brain_tumor_dataset/images/2/1906.png
# Saved image for /content/brain_tumor_dataset/extracted/2766.mat with label 2 at /content/brain_tumor_dataset/images/2/2766.png
# Saved image for /content/brain_tumor_dataset/extracted/437.mat with label 1 at /content/brain_tumor_dataset/images/1/437.png
# Saved image for /content/brain_tumor_dataset/extracted/1453.mat with label 3 at /content/brain_tumor_dataset/images/3/1453.png
# Saved image for /content/brain_tumor_dataset/extracted/416.mat with label 1 at /content/brain_tumor_dataset/images/1/416.png
# Saved image for /content/brain_tumor_dataset/extracted/1009.mat with label 3 at /content/brain_tumor_dataset/images/3/1009.png
# Saved image for /content/brain_tumor_dataset/extracted/636.mat with label 1 at /content/brain_tumor_dataset/images/1/636.png
# Saved image for /content/brain_tumor_dataset/extracted/556.mat with label 1 at /content/brain_tumor_dataset/images/1/556.png
# Saved image for /content/brain_tumor_dataset/extracted/1711.mat with label 3 at /content/brain_tumor_dataset/images/3/1711.png
# Saved image for /content/brain_tumor_dataset/extracted/2590.mat with label 2 at /content/brain_tumor_dataset/images/2/2590.png
# Saved image for /content/brain_tumor_dataset/extracted/2612.mat with label 2 at /content/brain_tumor_dataset/images/2/2612.png
# Saved image for /content/brain_tumor_dataset/extracted/1869.mat with label 2 at /content/brain_tumor_dataset/images/2/1869.png
# Saved image for /content/brain_tumor_dataset/extracted/2629.mat with label 2 at /content/brain_tumor_dataset/images/2/2629.png
# Saved image for /content/brain_tumor_dataset/extracted/169.mat with label 1 at /content/brain_tumor_dataset/images/1/169.png
# Saved image for /content/brain_tumor_dataset/extracted/1263.mat with label 3 at /content/brain_tumor_dataset/images/3/1263.png
# Saved image for /content/brain_tumor_dataset/extracted/1883.mat with label 2 at /content/brain_tumor_dataset/images/2/1883.png
# Saved image for /content/brain_tumor_dataset/extracted/2231.mat with label 2 at /content/brain_tumor_dataset/images/2/2231.png
# Saved image for /content/brain_tumor_dataset/extracted/673.mat with label 1 at /content/brain_tumor_dataset/images/1/673.png
# Saved image for /content/brain_tumor_dataset/extracted/761.mat with label 2 at /content/brain_tumor_dataset/images/2/761.png
# Saved image for /content/brain_tumor_dataset/extracted/2004.mat with label 2 at /content/brain_tumor_dataset/images/2/2004.png
# Saved image for /content/brain_tumor_dataset/extracted/883.mat with label 2 at /content/brain_tumor_dataset/images/2/883.png
# Saved image for /content/brain_tumor_dataset/extracted/535.mat with label 1 at /content/brain_tumor_dataset/images/1/535.png
# Saved image for /content/brain_tumor_dataset/extracted/315.mat with label 1 at /content/brain_tumor_dataset/images/1/315.png
# Saved image for /content/brain_tumor_dataset/extracted/2305.mat with label 2 at /content/brain_tumor_dataset/images/2/2305.png
# Saved image for /content/brain_tumor_dataset/extracted/2745.mat with label 2 at /content/brain_tumor_dataset/images/2/2745.png
# Saved image for /content/brain_tumor_dataset/extracted/1466.mat with label 3 at /content/brain_tumor_dataset/images/3/1466.png
# Saved image for /content/brain_tumor_dataset/extracted/469.mat with label 1 at /content/brain_tumor_dataset/images/1/469.png
# Saved image for /content/brain_tumor_dataset/extracted/1658.mat with label 3 at /content/brain_tumor_dataset/images/3/1658.png
# Saved image for /content/brain_tumor_dataset/extracted/423.mat with label 1 at /content/brain_tumor_dataset/images/1/423.png
# Saved image for /content/brain_tumor_dataset/extracted/1926.mat with label 2 at /content/brain_tumor_dataset/images/2/1926.png
# Saved image for /content/brain_tumor_dataset/extracted/2094.mat with label 2 at /content/brain_tumor_dataset/images/2/2094.png
# Saved image for /content/brain_tumor_dataset/extracted/1033.mat with label 3 at /content/brain_tumor_dataset/images/3/1033.png
# Saved image for /content/brain_tumor_dataset/extracted/738.mat with label 2 at /content/brain_tumor_dataset/images/2/738.png
# Saved image for /content/brain_tumor_dataset/extracted/1566.mat with label 3 at /content/brain_tumor_dataset/images/3/1566.png
# Saved image for /content/brain_tumor_dataset/extracted/1085.mat with label 3 at /content/brain_tumor_dataset/images/3/1085.png
# Saved image for /content/brain_tumor_dataset/extracted/639.mat with label 1 at /content/brain_tumor_dataset/images/1/639.png
# Saved image for /content/brain_tumor_dataset/extracted/2340.mat with label 2 at /content/brain_tumor_dataset/images/2/2340.png
# Saved image for /content/brain_tumor_dataset/extracted/1696.mat with label 3 at /content/brain_tumor_dataset/images/3/1696.png
# Saved image for /content/brain_tumor_dataset/extracted/286.mat with label 1 at /content/brain_tumor_dataset/images/1/286.png
# Saved image for /content/brain_tumor_dataset/extracted/89.mat with label 1 at /content/brain_tumor_dataset/images/1/89.png
# Saved image for /content/brain_tumor_dataset/extracted/2927.mat with label 2 at /content/brain_tumor_dataset/images/2/2927.png
# Saved image for /content/brain_tumor_dataset/extracted/1542.mat with label 3 at /content/brain_tumor_dataset/images/3/1542.png
# Saved image for /content/brain_tumor_dataset/extracted/1815.mat with label 3 at /content/brain_tumor_dataset/images/3/1815.png
# Saved image for /content/brain_tumor_dataset/extracted/2750.mat with label 2 at /content/brain_tumor_dataset/images/2/2750.png
# Saved image for /content/brain_tumor_dataset/extracted/1678.mat with label 3 at /content/brain_tumor_dataset/images/3/1678.png
# Saved image for /content/brain_tumor_dataset/extracted/106.mat with label 1 at /content/brain_tumor_dataset/images/1/106.png
# Saved image for /content/brain_tumor_dataset/extracted/296.mat with label 1 at /content/brain_tumor_dataset/images/1/296.png
# Saved image for /content/brain_tumor_dataset/extracted/1111.mat with label 3 at /content/brain_tumor_dataset/images/3/1111.png
# Saved image for /content/brain_tumor_dataset/extracted/14.mat with label 1 at /content/brain_tumor_dataset/images/1/14.png
# Saved image for /content/brain_tumor_dataset/extracted/197.mat with label 1 at /content/brain_tumor_dataset/images/1/197.png
# Saved image for /content/brain_tumor_dataset/extracted/362.mat with label 1 at /content/brain_tumor_dataset/images/1/362.png
# Saved image for /content/brain_tumor_dataset/extracted/1965.mat with label 2 at /content/brain_tumor_dataset/images/2/1965.png
# Saved image for /content/brain_tumor_dataset/extracted/1170.mat with label 3 at /content/brain_tumor_dataset/images/3/1170.png
# Saved image for /content/brain_tumor_dataset/extracted/2404.mat with label 2 at /content/brain_tumor_dataset/images/2/2404.png
# Saved image for /content/brain_tumor_dataset/extracted/1190.mat with label 3 at /content/brain_tumor_dataset/images/3/1190.png
# Saved image for /content/brain_tumor_dataset/extracted/2290.mat with label 2 at /content/brain_tumor_dataset/images/2/2290.png
# Saved image for /content/brain_tumor_dataset/extracted/874.mat with label 2 at /content/brain_tumor_dataset/images/2/874.png
# Saved image for /content/brain_tumor_dataset/extracted/2974.mat with label 2 at /content/brain_tumor_dataset/images/2/2974.png
# Saved image for /content/brain_tumor_dataset/extracted/1569.mat with label 3 at /content/brain_tumor_dataset/images/3/1569.png
# Saved image for /content/brain_tumor_dataset/extracted/774.mat with label 2 at /content/brain_tumor_dataset/images/2/774.png
# Saved image for /content/brain_tumor_dataset/extracted/560.mat with label 1 at /content/brain_tumor_dataset/images/1/560.png
# Saved image for /content/brain_tumor_dataset/extracted/422.mat with label 1 at /content/brain_tumor_dataset/images/1/422.png
# Saved image for /content/brain_tumor_dataset/extracted/183.mat with label 1 at /content/brain_tumor_dataset/images/1/183.png
# Saved image for /content/brain_tumor_dataset/extracted/43.mat with label 1 at /content/brain_tumor_dataset/images/1/43.png
# Saved image for /content/brain_tumor_dataset/extracted/338.mat with label 1 at /content/brain_tumor_dataset/images/1/338.png
# Saved image for /content/brain_tumor_dataset/extracted/473.mat with label 1 at /content/brain_tumor_dataset/images/1/473.png
# Saved image for /content/brain_tumor_dataset/extracted/159.mat with label 1 at /content/brain_tumor_dataset/images/1/159.png
# Saved image for /content/brain_tumor_dataset/extracted/114.mat with label 1 at /content/brain_tumor_dataset/images/1/114.png
# Saved image for /content/brain_tumor_dataset/extracted/428.mat with label 1 at /content/brain_tumor_dataset/images/1/428.png
# Saved image for /content/brain_tumor_dataset/extracted/2967.mat with label 2 at /content/brain_tumor_dataset/images/2/2967.png
# Saved image for /content/brain_tumor_dataset/extracted/2520.mat with label 2 at /content/brain_tumor_dataset/images/2/2520.png
# Saved image for /content/brain_tumor_dataset/extracted/157.mat with label 1 at /content/brain_tumor_dataset/images/1/157.png
# Processing complete.

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

output_dir = '/content/brain_tumor_dataset/images'

# Collect image paths and their labels
image_files = []
labels = []

for root, _, files in os.walk(output_dir):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(root, file)
            # Extract label from the subdirectory name
            label = os.path.basename(os.path.dirname(image_path))
            image_files.append(image_path)
            labels.append(label)

# Show first 8 images
num_images = min(8, len(image_files))
images_to_show = image_files[:num_images]
labels_to_show = labels[:num_images]

# Set up the plot
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i, (img_path, label) in enumerate(zip(images_to_show, labels_to_show)):
    img = Image.open(img_path)
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Label: {label}")
    axes[i].axis('off')

# Hide any unused subplots if less than 8 images
for j in range(i + 1, 8):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# Dictionary mapping numeric labels to tumor types
label_dict = {1: 'meningioma', 2: 'glioma', 3: 'pituitary'}

output_dir = '/content/brain_tumor_dataset/images'

# Collect image paths and their labels
image_files = []
labels = []

for root, _, files in os.walk(output_dir):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(root, file)

            label_num = os.path.basename(root)
            if not label_num.isdigit():
                continue

            label_str = label_dict.get(int(label_num), "Unknown")

            image_files.append(image_path)
            labels.append(label_str)


# Show first 8 images
num_images = min(8, len(image_files))
images_to_show = image_files[:num_images]
labels_to_show = labels[:num_images]

# Set up the plot
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i, (img_path, label) in enumerate(zip(images_to_show, labels_to_show)):
    img = Image.open(img_path)
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Label: {label}")
    axes[i].axis('off')

# Hide any unused subplots if less than 8 images
for j in range(i + 1, 8):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Dictionary mapping numeric labels to tumor types
label_dict = {1: 'meningioma', 2: 'glioma', 3: 'pituitary'}

output_dir = '/content/brain_tumor_dataset/images'

def preprocess_image(image_path):
    img = Image.open(image_path).convert('L')
    img = img.resize((256, 256))
    img_array = np.array(img).astype(np.float32)

    # Percentile clipping (2 to 98)
    p2, p98 = np.percentile(img_array, (2, 98))
    img_array = np.clip(img_array, p2, p98)

    # Normalize to [0,1]
    img_array = (img_array - p2) / (p98 - p2)

    # Gamma correction (darken)
    gamma = 0.4
    img_array = np.power(img_array, gamma)

    return img_array

# Collect image paths and their labels
image_files = []
labels = []

for root, _, files in os.walk(output_dir):
    label_num = os.path.basename(root)

    # Skip folders like 'images' that are not numbers
    if not label_num.isdigit():
        continue

    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(root, file)
            label_str = label_dict.get(int(label_num), "Unknown")

            image_files.append(image_path)
            labels.append(label_str)


# Show first 8 images with their processed versions side-by-side
num_images = min(4, len(image_files))
images_to_show = image_files[:num_images]
labels_to_show = labels[:num_images]

fig, axes = plt.subplots(num_images, 2, figsize=(10, 4 * num_images))

for i, (img_path, label) in enumerate(zip(images_to_show, labels_to_show)):
    # Original image
    img = Image.open(img_path)
    axes[i, 0].imshow(img, cmap='gray')
    axes[i, 0].set_title(f"Original: {label}")
    axes[i, 0].axis('off')

    # Processed image
    proc_img = preprocess_image(img_path)
    axes[i, 1].imshow(proc_img, cmap='gray')
    axes[i, 1].set_title(f"Processed: {label}")
    axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
import os
from PIL import Image, ImageEnhance
import numpy as np

# Dictionary mapping numeric labels to tumor types
label_dict = {1: 'meningioma', 2: 'glioma', 3: 'pituitary'}
output_dir = '/content/brain_tumor_dataset/images'

def preprocess_image(image_path):
    # Open image, convert to grayscale and resize
    img = Image.open(image_path).convert('L')
    img = img.resize((256, 256))

    # Apply sharpness enhancement
    enhancer = ImageEnhance.Sharpness(img)
    img = enhancer.enhance(2.5)  # Adjust factor as needed

    # Convert to numpy array
    img_array = np.array(img).astype(np.float32)

    # Percentile clipping (2nd to 98th percentile) to reduce outliers
    p2, p98 = np.percentile(img_array, (2, 98))
    img_array = np.clip(img_array, p2, p98)

    # Normalize to [0,1]
    img_array = (img_array - p2) / (p98 - p2)

    # Gamma correction (darken)
    gamma = 0.7
    img_array = np.power(img_array, gamma)

    return img_array

processed_images = []
processed_labels = []

max_per_class = 100
count_per_class = {label: 0 for label in label_dict.keys()}

for label_num, label_name in label_dict.items():
    class_folder = os.path.join(output_dir, str(label_num))
    if not os.path.exists(class_folder):
        print(f"Folder not found: {class_folder}")
        continue

    files = [f for f in os.listdir(class_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    for file in files:
        if count_per_class[label_num] >= max_per_class:
            break
        img_path = os.path.join(class_folder, file)
        try:
            processed_img = preprocess_image(img_path)
            processed_images.append(processed_img)
            processed_labels.append(label_name)
            count_per_class[label_num] += 1
        except Exception as e:
            print(f"Error processing {img_path}: {e}")

print("Processed images per class:", count_per_class)
print(f"Total processed images: {len(processed_images)}")
# Out:
# Processed images per class: {1: 100, 2: 100, 3: 100}
# Total processed images: 300

# %%
np.unique(processed_labels)
# Out:
# array(['glioma', 'meningioma', 'pituitary'], dtype='<U10')

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# processed_labels is a list of strings like 'meningioma', 'glioma', 'pituitary'

le = LabelEncoder()
numeric_labels = le.fit_transform(processed_labels)  # e.g. meningioma->0, glioma->1, pituitary->2

# If you want, you can save the mapping:
label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Label mapping:", label_mapping)

numeric_labels = np.array(numeric_labels)
processed_images_rgb = np.stack([processed_images]*3, axis=-1)  # shape: (num_samples, 256,256,3)
# Out:
# Label mapping: {np.str_('glioma'): np.int64(0), np.str_('meningioma'): np.int64(1), np.str_('pituitary'): np.int64(2)}

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.models import Model

INPUT_SHAPE = (256, 256, 3)
num_classes = 3

base_model1 = Xception(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

x = base_model1.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model1.input, outputs=output)

# Freeze base model layers (optional)
for layer in base_model1.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 127, 127,  │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 127, 127,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, 127, 127,  │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 125, 125,  │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, 125, 125,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, 125, 125,  │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, 125, 125,  │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, 125, 125,  │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, 125, 125,  │          0 │ block2_sepconv1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, 125, 125,  │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, 125, 125,  │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 63, 63,    │      8,192 │ block1_conv2_act… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 63, 63,    │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 63, 63,    │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 63, 63,    │          0 │ block2_pool[0][0… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, 63, 63,    │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, 63, 63,    │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, 63, 63,    │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, 63, 63,    │          0 │ block3_sepconv1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, 63, 63,    │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, 63, 63,    │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │     32,768 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 32, 32,    │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ block3_pool[0][0… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, 32, 32,    │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, 32, 32,    │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, 32, 32,    │          0 │ block4_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, 32, 32,    │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, 32, 32,    │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │    186,368 │ add_1[0][0]       │
# │                     │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 16, 16,    │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,912 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 16,    │          0 │ block4_pool[0][0… │
# │                     │ 728)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, 16, 16,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, 16, 16,    │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, 16, 16,    │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, 16, 16,    │          0 │ block5_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, 16, 16,    │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, 16, 16,    │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, 16, 16,    │          0 │ block5_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, 16, 16,    │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, 16, 16,    │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ block5_sepconv3_… │
# │                     │ 728)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, 16, 16,    │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, 16, 16,    │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, 16, 16,    │          0 │ block6_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, 16, 16,    │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, 16, 16,    │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, 16, 16,    │          0 │ block6_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, 16, 16,    │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, 16, 16,    │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 16,    │          0 │ block6_sepconv3_… │
# │                     │ 728)              │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, 16, 16,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, 16, 16,    │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, 16, 16,    │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, 16, 16,    │          0 │ block7_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, 16, 16,    │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, 16, 16,    │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, 16, 16,    │          0 │ block7_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, 16, 16,    │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, 16, 16,    │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 16,    │          0 │ block7_sepconv3_… │
# │                     │ 728)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, 16, 16,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, 16, 16,    │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, 16, 16,    │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, 16, 16,    │          0 │ block8_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, 16, 16,    │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, 16, 16,    │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, 16, 16,    │          0 │ block8_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, 16, 16,    │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, 16, 16,    │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 16, 16,    │          0 │ block8_sepconv3_… │
# │                     │ 728)              │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, 16, 16,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, 16, 16,    │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, 16, 16,    │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, 16, 16,    │          0 │ block9_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, 16, 16,    │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, 16, 16,    │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, 16, 16,    │          0 │ block9_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, 16, 16,    │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, 16, 16,    │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 16,    │          0 │ block9_sepconv3_… │
# │                     │ 728)              │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, 16, 16,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, 16, 16,    │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, 16, 16,    │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, 16, 16,    │          0 │ block10_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, 16, 16,    │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, 16, 16,    │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, 16, 16,    │          0 │ block10_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, 16, 16,    │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, 16, 16,    │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 16, 16,    │          0 │ block10_sepconv3… │
# │                     │ 728)              │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, 16, 16,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, 16, 16,    │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, 16, 16,    │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, 16, 16,    │          0 │ block11_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, 16, 16,    │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, 16, 16,    │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, 16, 16,    │          0 │ block11_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, 16, 16,    │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, 16, 16,    │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 16, 16,    │          0 │ block11_sepconv3… │
# │                     │ 728)              │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, 16, 16,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, 16, 16,    │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, 16, 16,    │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, 16, 16,    │          0 │ block12_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, 16, 16,    │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, 16, 16,    │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, 16, 16,    │          0 │ block12_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, 16, 16,    │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, 16, 16,    │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 16, 16,    │          0 │ block12_sepconv3… │
# │                     │ 728)              │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, 16, 16,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, 16, 16,    │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, 16, 16,    │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, 16, 16,    │          0 │ block13_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, 16, 16,    │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, 16, 16,    │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 8, 8,      │    745,472 │ add_10[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, 8, 8,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 8, 8,      │          0 │ block13_pool[0][… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, 8, 8,      │  1,582,080 │ add_11[0][0]      │
# │ (SeparableConv2D)   │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, 8, 8,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, 8, 8,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, 8, 8,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, 8, 8,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, 8, 8,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ block14_sepconv2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │      6,147 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,867,627 (79.60 MB)
#  Trainable params: 6,147 (24.01 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
import numpy as np
import os
from sklearn.model_selection import KFold
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             confusion_matrix, classification_report, cohen_kappa_score,
                             matthews_corrcoef)
from scipy import stats
import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# === Parameters ===
num_classes = 3
INPUT_SHAPE = (256, 256, 3)  # Assuming processed_images_rgb shape is consistent with this
EPOCHS = 3
BATCH_SIZE = 32

# Assume processed_images_rgb is your preprocessed RGB images as numpy array (N, 256, 256, 3)
# Assume numeric_labels is a numpy array of integer labels (N,) with values in [0, num_classes-1]

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Storage for fold metrics
fold_metrics = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': [],
    'kappa': [],
    'mcc': [],
    'csi': [],
    'conf_matrices': [],
    'classification_reports': []
}

fold_no = 1

def compute_csi(conf_matrix):
    csi_per_class = []
    for i in range(len(conf_matrix)):
        TP = conf_matrix[i, i]
        FN = conf_matrix[i, :].sum() - TP
        FP = conf_matrix[:, i].sum() - TP
        denom = TP + FN + FP
        csi = TP / denom if denom > 0 else 0
        csi_per_class.append(csi)
    return np.mean(csi_per_class)

def accuracy_confidence_interval(acc, n, confidence=0.95):
    z = stats.norm.ppf(1 - (1 - confidence) / 2)
    se = np.sqrt((acc * (1 - acc)) / n)
    lower = acc - z * se
    upper = acc + z * se
    return max(0, lower), min(1, upper)

for train_index, val_index in kf.split(processed_images_rgb):
    print(f"Training fold {fold_no}...")

    X_train, X_val = processed_images_rgb[train_index], processed_images_rgb[val_index]
    y_train, y_val = numeric_labels[train_index], numeric_labels[val_index]

    # Build model fresh for each fold
    base_model = Xception(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    output = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)

    # Freeze base model layers (optional)
    for layer in base_model.layers:
        layer.trainable = False

    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Train model
    model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
              validation_data=(X_val, y_val), verbose=2)

    # Predictions
    y_pred_probs = model.predict(X_val)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Basic metrics
    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_val, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_val, y_pred, average='weighted', zero_division=0)

    # Additional metrics
    conf_mat = confusion_matrix(y_val, y_pred)
    class_report = classification_report(y_val, y_pred, zero_division=0)
    kappa = cohen_kappa_score(y_val, y_pred)
    mcc = matthews_corrcoef(y_val, y_pred)
    csi = compute_csi(conf_mat)
    ci_lower, ci_upper = accuracy_confidence_interval(acc, len(y_val))

    # Print metrics
    print(f"Fold {fold_no} metrics:")
    print(f"Accuracy: {acc:.4f} (95% CI: [{ci_lower:.4f}, {ci_upper:.4f}])")
    print(f"Precision: {prec:.4f}, Recall: {rec:.4f}, F1 Score: {f1:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}, MCC: {mcc:.4f}, CSI: {csi:.4f}")
    print("Confusion Matrix:")
    print(conf_mat)
    print("Classification Report:")
    print(class_report)

    # Save metrics for averaging/reporting later
    fold_metrics['accuracy'].append(acc)
    fold_metrics['precision'].append(prec)
    fold_metrics['recall'].append(rec)
    fold_metrics['f1_score'].append(f1)
    fold_metrics['kappa'].append(kappa)
    fold_metrics['mcc'].append(mcc)
    fold_metrics['csi'].append(csi)
    fold_metrics['conf_matrices'].append(conf_mat)
    fold_metrics['classification_reports'].append(class_report)

    fold_no += 1

# Average metrics over folds
print("\n=== 5-Fold Cross-Validation Average Results ===")
print(f"Average Accuracy: {np.mean(fold_metrics['accuracy']):.4f}")
print(f"Average Precision: {np.mean(fold_metrics['precision']):.4f}")
print(f"Average Recall: {np.mean(fold_metrics['recall']):.4f}")
print(f"Average F1 Score: {np.mean(fold_metrics['f1_score']):.4f}")
print(f"Average Cohen's Kappa: {np.mean(fold_metrics['kappa']):.4f}")
print(f"Average MCC: {np.mean(fold_metrics['mcc']):.4f}")
print(f"Average CSI: {np.mean(fold_metrics['csi']):.4f}")
# Out:
# Training fold 1...
# Epoch 1/3

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             confusion_matrix, classification_report, cohen_kappa_score,
                             matthews_corrcoef)
from scipy import stats
import tensorflow as tf
from tensorflow.keras.applications import Xception, ResNet50V2, ResNet152V2, InceptionResNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# === Parameters ===
num_classes = 3
INPUT_SHAPE = (256, 256, 3)  # Adjust as needed
EPOCHS = 3
BATCH_SIZE = 32

# Assume these are your data arrays
# processed_images_rgb: np.array of shape (N, 256, 256, 3)
# numeric_labels: np.array of shape (N,) with integer labels [0, num_classes-1]

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Model dictionary to loop over
base_models_dict = {
    'Xception': Xception,
    'ResNet50V2': ResNet50V2,
    'ResNet152V2': ResNet152V2,
    'InceptionResNetV2': InceptionResNetV2
}

def compute_csi(conf_matrix):
    csi_per_class = []
    for i in range(len(conf_matrix)):
        TP = conf_matrix[i, i]
        FN = conf_matrix[i, :].sum() - TP
        FP = conf_matrix[:, i].sum() - TP
        denom = TP + FN + FP
        csi = TP / denom if denom > 0 else 0
        csi_per_class.append(csi)
    return np.mean(csi_per_class)

def accuracy_confidence_interval(acc, n, confidence=0.95):
    z = stats.norm.ppf(1 - (1 - confidence) / 2)
    se = np.sqrt((acc * (1 - acc)) / n)
    lower = acc - z * se
    upper = acc + z * se
    return max(0, lower), min(1, upper)

# To store results for each model
results = {model_name: {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': [],
    'kappa': [],
    'mcc': [],
    'csi': [],
    'conf_matrices': [],
    'classification_reports': []
} for model_name in base_models_dict.keys()}

# Loop over folds
for fold_no, (train_index, val_index) in enumerate(kf.split(processed_images_rgb), 1):
    print(f"\n===== Fold {fold_no} =====")

    X_train, X_val = processed_images_rgb[train_index], processed_images_rgb[val_index]
    y_train, y_val = numeric_labels[train_index], numeric_labels[val_index]

    # Loop over each base model
    for model_name, base_model_func in base_models_dict.items():
        print(f"\nTraining with base model: {model_name}")

        # Build fresh model
        base_model = base_model_func(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
        x = base_model.output
        x = GlobalAveragePooling2D()(x)
        x = Dropout(0.5)(x)
        output = Dense(num_classes, activation='softmax')(x)
        model = Model(inputs=base_model.input, outputs=output)

        # Freeze base layers optionally
        for layer in base_model.layers:
            layer.trainable = False

        model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

        # Train
        model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
                  validation_data=(X_val, y_val), verbose=2)

        # Predict
        y_pred_probs = model.predict(X_val)
        y_pred = np.argmax(y_pred_probs, axis=1)

        # Metrics
        acc = accuracy_score(y_val, y_pred)
        prec = precision_score(y_val, y_pred, average='weighted', zero_division=0)
        rec = recall_score(y_val, y_pred, average='weighted', zero_division=0)
        f1 = f1_score(y_val, y_pred, average='weighted', zero_division=0)
        conf_mat = confusion_matrix(y_val, y_pred)
        class_report = classification_report(y_val, y_pred, zero_division=0)
        kappa = cohen_kappa_score(y_val, y_pred)
        mcc = matthews_corrcoef(y_val, y_pred)
        csi = compute_csi(conf_mat)
        ci_lower, ci_upper = accuracy_confidence_interval(acc, len(y_val))

        print(f"Metrics for {model_name} on fold {fold_no}:")
        print(f"Accuracy: {acc:.4f} (95% CI: [{ci_lower:.4f}, {ci_upper:.4f}])")
        print(f"Precision: {prec:.4f}, Recall: {rec:.4f}, F1 Score: {f1:.4f}")
        print(f"Cohen's Kappa: {kappa:.4f}, MCC: {mcc:.4f}, CSI: {csi:.4f}")
        print("Confusion Matrix:")
        print(conf_mat)
        print("Classification Report:")
        print(class_report)

        # Save metrics for averages
        results[model_name]['accuracy'].append(acc)
        results[model_name]['precision'].append(prec)
        results[model_name]['recall'].append(rec)
        results[model_name]['f1_score'].append(f1)
        results[model_name]['kappa'].append(kappa)
        results[model_name]['mcc'].append(mcc)
        results[model_name]['csi'].append(csi)
        results[model_name]['conf_matrices'].append(conf_mat)
        results[model_name]['classification_reports'].append(class_report)

# After all folds & models are done, print average results per model
print("\n\n=== Average 5-Fold CV Results per Model ===")
for model_name in base_models_dict.keys():
    print(f"\nModel: {model_name}")
    print(f"Average Accuracy: {np.mean(results[model_name]['accuracy']):.4f}")
    print(f"Average Precision: {np.mean(results[model_name]['precision']):.4f}")
    print(f"Average Recall: {np.mean(results[model_name]['recall']):.4f}")
    print(f"Average F1 Score: {np.mean(results[model_name]['f1_score']):.4f}")
    print(f"Average Cohen's Kappa: {np.mean(results[model_name]['kappa']):.4f}")
    print(f"Average MCC: {np.mean(results[model_name]['mcc']):.4f}")
    print(f"Average CSI: {np.mean(results[model_name]['csi']):.4f}")

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score
import tensorflow as tf
from tensorflow.keras.applications import Xception, ResNet50V2, ResNet152V2, InceptionResNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from itertools import product

# === Parameters ===
num_classes = 3
INPUT_SHAPE = (256, 256, 3)
EPOCHS = 3
BATCH_SIZE = 32

kf = KFold(n_splits=5, shuffle=True, random_state=42)

base_models_dict = {
    'Xception': Xception,
    'ResNet50V2': ResNet50V2,
    'ResNet152V2': ResNet152V2,
    'InceptionResNetV2': InceptionResNetV2
}

# Build model function for reusability
def build_model(base_model_func):
    base_model = base_model_func(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    output = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Generate all possible weight combinations with step 0.1 summing to 1
def generate_weight_combinations(step=0.1):
    weights_range = np.arange(0, 1 + step, step)
    combos = []
    for combo in product(weights_range, repeat=4):
        if abs(sum(combo) - 1.0) < 1e-6:
            combos.append(combo)
    return combos

weight_combinations = generate_weight_combinations(0.1)

fold_no = 1
fold_metrics = []
fold_best_weights = []

for train_idx, val_idx in kf.split(processed_images_rgb):
    print(f"\n=== Fold {fold_no} ===")

    X_train, X_val = processed_images_rgb[train_idx], processed_images_rgb[val_idx]
    y_train, y_val = numeric_labels[train_idx], numeric_labels[val_idx]

    # Train each model and predict probs
    model_preds = {}
    for model_name, base_model_func in base_models_dict.items():
        print(f"Training {model_name}...")
        model = build_model(base_model_func)
        model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(X_val, y_val), verbose=2)
        preds = model.predict(X_val)  # shape (val_samples, num_classes)
        model_preds[model_name] = preds

    # Grid search over weights for best accuracy (can change metric)
    best_acc = 0
    best_weights = None
    best_weighted_pred = None

    for weights in weight_combinations:
        # Weighted sum of predictions from all models
        weighted_preds = np.zeros_like(model_preds['Xception'])
        for w, model_name in zip(weights, base_models_dict.keys()):
            weighted_preds += w * model_preds[model_name]

        weighted_pred_labels = np.argmax(weighted_preds, axis=1)
        acc = accuracy_score(y_val, weighted_pred_labels)

        if acc > best_acc:
            best_acc = acc
            best_weights = weights
            best_weighted_pred = weighted_pred_labels

    print(f"Best weights for fold {fold_no}: {best_weights} with Accuracy: {best_acc:.4f}")

    # Store fold results
    fold_metrics.append({
        'accuracy': best_acc,
        'weights': best_weights
    })
    fold_best_weights.append(best_weights)

    fold_no += 1
    break

# Summarize results
avg_accuracy = np.mean([m['accuracy'] for m in fold_metrics])
print("\n=== Final results over all folds ===")
print(f"Average Weighted Accuracy: {avg_accuracy:.4f}")
print("Weights chosen per fold:")
for i, w in enumerate(fold_best_weights, 1):
    print(f"Fold {i}: {w}")




import numpy as np
from sklearn.metrics import accuracy_score
from deap import base, creator, tools, algorithms
import random

# GA parameters
POP_SIZE = 50
NGEN = 40
CXPB = 0.7  # Crossover probability
MUTPB = 0.2  # Mutation probability

def ga_optimize_weights(model_preds, y_true):
    """
    model_preds: dict of model_name -> np.array of shape (samples, classes)
    y_true: true labels array of shape (samples,)

    Returns: best weights (tuple of length 4) that maximize accuracy.
    """

    # Fitness function: maximize accuracy of weighted sum
    def fitness(individual):
        weights = np.array(individual)
        weights = weights / weights.sum()  # normalize weights to sum=1
        combined_pred = np.zeros_like(list(model_preds.values())[0])
        for w, pred in zip(weights, model_preds.values()):
            combined_pred += w * pred
        pred_labels = np.argmax(combined_pred, axis=1)
        acc = accuracy_score(y_true, pred_labels)
        return (acc,)  # DEAP expects fitness to be a tuple

    # Set up GA with DEAP
    creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # maximize accuracy
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()
    # Each individual is 4 weights initialized randomly between 0 and 1
    toolbox.register("attr_float", random.random)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=4)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    toolbox.register("evaluate", fitness)
    toolbox.register("mate", tools.cxBlend, alpha=0.5)
    toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.1, indpb=0.2)
    toolbox.register("select", tools.selTournament, tournsize=3)

    pop = toolbox.population(n=POP_SIZE)

    # Apply genetic algorithm
    hof = tools.HallOfFame(1)  # Keep best individual

    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("max", np.max)

    algorithms.eaSimple(pop, toolbox, cxpb=CXPB, mutpb=MUTPB, ngen=NGEN,
                        stats=stats, halloffame=hof, verbose=False)

    # Normalize best weights to sum=1
    best_weights = np.array(hof[0])
    best_weights /= best_weights.sum()

    return tuple(best_weights)


# === Inside your fold training loop, after you train all 4 models and get predictions ===

for train_idx, val_idx in kf.split(processed_images_rgb):
    print(f"\n=== Fold {fold_no} ===")

    X_train, X_val = processed_images_rgb[train_idx], processed_images_rgb[val_idx]
    y_train, y_val = numeric_labels[train_idx], numeric_labels[val_idx]

    model_preds = {}
    for model_name, base_model_func in base_models_dict.items():
        print(f"Training {model_name}...")
        model = build_model(base_model_func)
        model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(X_val, y_val), verbose=2)
        preds = model.predict(X_val)
        model_preds[model_name] = preds

    # GA optimization of weights
    best_weights = ga_optimize_weights(model_preds, y_val)

    print(f"Best GA weights for fold {fold_no}: {best_weights}")

    # Calculate final predictions using best weights
    combined_preds = np.zeros_like(list(model_preds.values())[0])
    for w, pred in zip(best_weights, model_preds.values()):
        combined_preds += w * pred
    pred_labels = np.argmax(combined_preds, axis=1)

    acc = accuracy_score(y_val, pred_labels)
    f1 = f1_score(y_val, pred_labels, average='weighted')

    print(f"Fold {fold_no} - Accuracy: {acc:.4f}, F1-score: {f1:.4f}")

    fold_metrics.append({'accuracy': acc, 'f1_score': f1, 'weights': best_weights})

    fold_no += 1

# %%
# !pip install deap

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from deap import base, creator, tools, algorithms
import random

# GA parameters
POP_SIZE = 50
NGEN = 40
CXPB = 0.7  # Crossover probability
MUTPB = 0.2  # Mutation probability

def ga_optimize_weights(model_preds, y_true):
    """
    model_preds: dict of model_name -> np.array of shape (samples, classes)
    y_true: true labels array of shape (samples,)

    Returns: best weights (tuple of length 4) that maximize accuracy.
    """

    # Fitness function: maximize accuracy of weighted sum
    def fitness(individual):
        weights = np.array(individual)
        weights = weights / weights.sum()  # normalize weights to sum=1
        combined_pred = np.zeros_like(list(model_preds.values())[0])
        for w, pred in zip(weights, model_preds.values()):
            combined_pred += w * pred
        pred_labels = np.argmax(combined_pred, axis=1)
        acc = accuracy_score(y_true, pred_labels)
        return (acc,)  # DEAP expects fitness to be a tuple

    # Set up GA with DEAP
    creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # maximize accuracy
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()
    # Each individual is 4 weights initialized randomly between 0 and 1
    toolbox.register("attr_float", random.random)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=4)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    toolbox.register("evaluate", fitness)
    toolbox.register("mate", tools.cxBlend, alpha=0.5)
    toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.1, indpb=0.2)
    toolbox.register("select", tools.selTournament, tournsize=3)

    pop = toolbox.population(n=POP_SIZE)

    # Apply genetic algorithm
    hof = tools.HallOfFame(1)  # Keep best individual

    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("max", np.max)

    algorithms.eaSimple(pop, toolbox, cxpb=CXPB, mutpb=MUTPB, ngen=NGEN,
                        stats=stats, halloffame=hof, verbose=False)

    # Normalize best weights to sum=1
    best_weights = np.array(hof[0])
    best_weights /= best_weights.sum()

    return tuple(best_weights)


# === Inside your fold training loop, after you train all 4 models and get predictions ===

for train_idx, val_idx in kf.split(processed_images_rgb):
    print(f"\n=== Fold {fold_no} ===")

    X_train, X_val = processed_images_rgb[train_idx], processed_images_rgb[val_idx]
    y_train, y_val = numeric_labels[train_idx], numeric_labels[val_idx]

    model_preds = {}
    for model_name, base_model_func in base_models_dict.items():
        print(f"Training {model_name}...")
        model = build_model(base_model_func)
        model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(X_val, y_val), verbose=2)
        preds = model.predict(X_val)
        model_preds[model_name] = preds

    # GA optimization of weights
    best_weights = ga_optimize_weights(model_preds, y_val)

    print(f"Best GA weights for fold {fold_no}: {best_weights}")

    # Calculate final predictions using best weights
    combined_preds = np.zeros_like(list(model_preds.values())[0])
    for w, pred in zip(best_weights, model_preds.values()):
        combined_preds += w * pred
    pred_labels = np.argmax(combined_preds, axis=1)

    acc = accuracy_score(y_val, pred_labels)
    f1 = f1_score(y_val, pred_labels, average='weighted')

    print(f"Fold {fold_no} - Accuracy: {acc:.4f}, F1-score: {f1:.4f}")

    fold_metrics.append({'accuracy': acc, 'f1_score': f1, 'weights': best_weights})

    fold_no += 1

# %%
import numpy as np
import random
import os
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, classification_report, cohen_kappa_score, matthews_corrcoef
from tensorflow.keras.applications import Xception, ResNet50V2, ResNet152V2, InceptionResNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from deap import base, creator, tools, algorithms

# Parameters
INPUT_SHAPE = (256, 256, 3)
BATCH_SIZE = 32
EPOCHS = 3
NUM_CLASSES = 3

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Models dictionary
base_models_dict = {
    "Xception": Xception(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE),
    "ResNet50V2": ResNet50V2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE),
    "ResNet152V2": ResNet152V2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE),
    "InceptionResNetV2": InceptionResNetV2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
}

# GA Parameters
POP_SIZE = 50
NGEN = 40
CXPB = 0.7
MUTPB = 0.2

# Grid search weight space (0.1 increments, constrained to sum=1)
weight_space = np.round(np.linspace(0, 1, 11), 2)
weight_combinations = [(w1, w2, w3, w4) for w1 in weight_space for w2 in weight_space
                       for w3 in weight_space for w4 in weight_space
                       if np.isclose(w1 + w2 + w3 + w4, 1)]

fold_metrics = []
fold_no = 1

# Define the model building function
def build_model(base_model):
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    output = Dense(NUM_CLASSES, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)

    # Freeze base model layers
    for layer in base_model.layers:
        layer.trainable = False

    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# GA Optimization Function
def ga_optimize_weights(model_preds, y_true):
    """
    GA optimization of ensemble weights.
    """
    def fitness(individual):
        weights = np.array(individual)
        weights /= weights.sum()
        combined_pred = np.zeros_like(list(model_preds.values())[0])
        for w, pred in zip(weights, model_preds.values()):
            combined_pred += w * pred
        pred_labels = np.argmax(combined_pred, axis=1)
        return (accuracy_score(y_true, pred_labels),)

    creator.create("FitnessMax", base.Fitness, weights=(1.0,))
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()
    toolbox.register("attr_float", random.random)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=4)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    toolbox.register("evaluate", fitness)
    toolbox.register("mate", tools.cxBlend, alpha=0.5)
    toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.1, indpb=0.2)
    toolbox.register("select", tools.selTournament, tournsize=3)

    pop = toolbox.population(n=POP_SIZE)
    hof = tools.HallOfFame(1)

    algorithms.eaSimple(pop, toolbox, cxpb=CXPB, mutpb=MUTPB, ngen=NGEN, halloffame=hof, verbose=False)
    best_weights = np.array(hof[0])
    best_weights /= best_weights.sum()
    return tuple(best_weights)

# Training Loop
for train_idx, val_idx in kf.split(processed_images_rgb):
    print(f"\n=== Fold {fold_no} ===")

    X_train, X_val = processed_images_rgb[train_idx], processed_images_rgb[val_idx]
    y_train, y_val = numeric_labels[train_idx], numeric_labels[val_idx]

    model_preds = {}

    # Train and store predictions for each model
    for model_name, base_model_func in base_models_dict.items():
        print(f"Training {model_name}...")
        model = build_model(base_model_func)
        model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(X_val, y_val), verbose=2)
        preds = model.predict(X_val)
        model_preds[model_name] = preds

    # Grid Search
    print("Performing Grid Search...")
    best_acc = -1
    best_weights_grid = None

    for weights in weight_combinations:
        combined_pred = np.zeros_like(list(model_preds.values())[0])
        for w, pred in zip(weights, model_preds.values()):
            combined_pred += w * pred
        pred_labels = np.argmax(combined_pred, axis=1)
        acc = accuracy_score(y_val, pred_labels)
        if acc > best_acc:
            best_acc = acc
            best_weights_grid = weights

    print(f"Best Grid Search Weights: {best_weights_grid}, Accuracy: {best_acc:.4f}")

    # GA Optimization
    print("Performing GA Optimization...")
    best_weights_ga = ga_optimize_weights(model_preds, y_val)
    print(f"Best GA Weights: {best_weights_ga}")

    # Evaluate Grid and GA
    for method, weights in zip(["Grid Search", "GA"], [best_weights_grid, best_weights_ga]):
        combined_pred = np.zeros_like(list(model_preds.values())[0])
        for w, pred in zip(weights, model_preds.values()):
            combined_pred += w * pred
        pred_labels = np.argmax(combined_pred, axis=1)

        acc = accuracy_score(y_val, pred_labels)
        f1 = f1_score(y_val, pred_labels, average='weighted')
        prec = precision_score(y_val, pred_labels, average='weighted')
        rec = recall_score(y_val, pred_labels, average='weighted')
        kappa = cohen_kappa_score(y_val, pred_labels)
        mcc = matthews_corrcoef(y_val, pred_labels)
        cm = confusion_matrix(y_val, pred_labels)

        print(f"\n{method} - Fold {fold_no} Metrics:")
        print(f"Accuracy: {acc:.4f}, F1 Score: {f1:.4f}, Precision: {prec:.4f}, Recall: {rec:.4f}")
        print(f"Kappa: {kappa:.4f}, MCC: {mcc:.4f}")
        print(f"Confusion Matrix:\n{cm}")

        fold_metrics.append({
            'fold': fold_no,
            'method': method,
            'weights': weights,
            'accuracy': acc,
            'f1_score': f1,
            'precision': prec,
            'recall': rec,
            'kappa': kappa,
            'mcc': mcc,
            'conf_matrix': cm.tolist()
        })

    fold_no += 1

    break

# Average metrics across folds
for method in ["Grid Search", "GA"]:
    method_metrics = [m for m in fold_metrics if m['method'] == method]
    avg_acc = np.mean([m['accuracy'] for m in method_metrics])
    avg_f1 = np.mean([m['f1_score'] for m in method_metrics])

    print(f"\n=== {method} - Average Metrics Across Folds ===")
    print(f"Average Accuracy: {avg_acc:.4f}, Average F1 Score: {avg_f1:.4f}")

# %%
best_weights_grid

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.applications import Xception, ResNet50V2, ResNet152V2, InceptionResNetV2
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications.xception import preprocess_input
import tensorflow as tf

# Test image path (modify with actual test image path)
TEST_IMAGE_PATH = '/content/brain_tumor_dataset/images/1/10.png'

# Example weights for Xception, ResNet50V2, ResNet152V2, InceptionResNetV2
best_weights_grid = [0.93, 0.925, 0.92, 0.925] # SAMPLE WEIGHTS

# Number of classes
NUM_CLASSES = 3
INPUT_SHAPE = (256, 256, 3)

# ✅ Preprocessing the test image for model prediction
def preprocess_image(img_path):
    img = load_img(img_path, target_size=INPUT_SHAPE[:2])
    img_array = img_to_array(img)
    img_array = preprocess_input(img_array)  # Model-specific preprocessing
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# ✅ Function to read and prepare the original image for display
def load_original_image(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"Error: Unable to read image from {img_path}")
        return None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, INPUT_SHAPE[:2])
    img = img.astype('float32') / 255.0  # Normalize for display
    return img

# Load and preprocess the test image
img_array = preprocess_image(TEST_IMAGE_PATH)
original_img = load_original_image(TEST_IMAGE_PATH)

# ✅ Models dictionary with the same order as the weights
models_dict = {
    "Xception": Xception(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE),
    "ResNet50V2": ResNet50V2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE),
    "ResNet152V2": ResNet152V2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE),
    "InceptionResNetV2": InceptionResNetV2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
}

# ✅ Build the top layers for each model
def build_model(base_model):
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    output = Dense(NUM_CLASSES, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

# ✅ Load the models
ensemble_models = {name: build_model(model) for name, model in models_dict.items()}

# ✅ Weighted ensemble prediction
def weighted_ensemble_prediction(models, img_array, weights):
    preds = np.zeros((1, NUM_CLASSES))
    for (model_name, model), weight in zip(models.items(), weights):
        pred = model.predict(img_array)
        preds += weight * pred
    return preds

# ✅ Grad-CAM Implementation
def get_gradcam_heatmap(model, img_array, class_idx, last_conv_layer_name):
    grad_model = Model(inputs=model.inputs, outputs=[model.get_layer(last_conv_layer_name).output, model.output])
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, class_idx]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_sum(pooled_grads * conv_outputs, axis=-1)
    heatmap = tf.maximum(heatmap, 0) / tf.reduce_max(heatmap)
    return heatmap.numpy()

# ✅ Overlay heatmap on the original image
def overlay_heatmap(original_img, heatmap, alpha=0.5, colormap=cv2.COLORMAP_JET):
    heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, colormap)
    overlay = cv2.addWeighted((original_img * 255).astype(np.uint8), alpha, heatmap, 1 - alpha, 0)
    return overlay

# ✅ Get the predicted class from the ensemble
ensemble_pred = weighted_ensemble_prediction(ensemble_models, img_array, best_weights_grid)
predicted_class = np.argmax(ensemble_pred[0])

# ✅ Last convolutional layer names for each model
last_conv_layers = {
    "Xception": "block14_sepconv2_act",
    "ResNet50V2": "conv5_block3_out",
    "ResNet152V2": "conv5_block3_out",
    "InceptionResNetV2": "conv_7b_ac"
}

# ✅ Generate and display Grad-CAM visualizations
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i, (model_name, model) in enumerate(ensemble_models.items()):
    print(f"Generating Grad-CAM for {model_name}...")
    last_conv_layer_name = last_conv_layers[model_name]
    heatmap = get_gradcam_heatmap(model, img_array, predicted_class, last_conv_layer_name)
    overlay_img = overlay_heatmap(original_img, heatmap)

    # Original Image
    axes[i * 2].imshow(original_img)
    axes[i * 2].set_title(f"Original - {model_name}")
    axes[i * 2].axis('off')

    # Grad-CAM Image
    axes[i * 2 + 1].imshow(overlay_img)
    axes[i * 2 + 1].set_title(f"Grad-CAM - {model_name}")
    axes[i * 2 + 1].axis('off')

plt.tight_layout()
plt.show()
